# %%
import qcdloop as ql
td = ql.QCDLoop()
import vegas
import numpy as np

pb_convert = 3.894E8 # conversion factor GeV^-2 -> pb
m_Z = 91.1876    # Z boson mass
Gam_Z = 2.4414 # Z boson width
alpha = 1 / 132.184 # alpha QED
Gfermi = 1.1663787E-5 # fermi constant
SW2 = 0.223013 # sin^2(weinberg angle)
CW2 = 1 - SW2 # cos^2(weinberg angle)

m_Z2 = m_Z ** 2
alpha2 = alpha ** 2
SW = np.sqrt(SW2)
CW = np.sqrt(CW2)


m_h = 125.1 ## Higgs boson mass from Nierste paper
m_h2 = m_h ** 2
Me = 0.00051 ## Electron mass from particle data group (pdg)
MW = 80.379 ## W boson mass from Nierste paper
MW2 = MW ** 2
m_m = 0.105658 ## Muon mass from pdg

m_t = 173.1
m_t2 = m_t**2

mu2 = m_h2

E_phot_min = 5 
s_max_fix = m_h ** 2 - 2 * m_h * E_phot_min
m =  m_m
m2 = m ** 2


int1 = 1 + 1j
int2 = 1 + 1j
int3 = 1 + 1j
int4 = 1 + 1j
int5 = 1 + 1j
int6 = 1 + 1j
int7 = 1 + 1j
int8 = 1 + 1j
int9 = 1 + 1j
int10 = 1 + 1j
int11 = 1 + 1j
int12 = 1 + 1j
int13 = 1 + 1j
int14 = 1 + 1j
int15 = 1 + 1j
int16 = 1 + 1j
int17 = 1 + 1j
int18 = 1 + 1j
int19 = 1 + 1j
int20 = 1 + 1j
int21 = 1 + 1j
int22 = 1 + 1j
int23 = 1 + 1j
int24 = 1 + 1j
int25 = 1 + 1j
int26 = 1 + 1j


def coeff_a1(s, t):
    #u = (m_h**2) + (2*(m**2)) - s - t
    #beta = np.sqrt(1 - (4*((m**2)/s)))
    #costh = (((2*(m**2)) + (m_h**2) - s - (2*u)) / ((m_h**2) - s)) / beta
    #sinth = np.sqrt(1 - (costh**2))
    #y23 = (((4*s*(m_h**2)) + ((s-(m_h**2))*beta*costh*((2*(m_h*2))+(2*s))) + (((2*(m_h**4))+(2*(s**2)))*(beta**2)*(costh**2))) / (4*(m_h**2))) + ((s*(beta**2)*(sinth**2)) / 2)
    #y24 = t - (m**2)

    
    #y24 = 1653.67
    #y34 = 5647.51
    #y23 = 8323.8
    
    y23 = s
    y24 = t

        
    a1 = ((2*alpha2*int21*m_Z*SW)/(CW*CW2) - (2*alpha2*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) + 
    (2*alpha2*int2*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
    (2*alpha2*int5*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) + 
    (32*alpha2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) - 
    (32*alpha2*int1*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) + 
    (32*alpha2*int4*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) - 
    (12*alpha2*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) + 
    (12*alpha2*int2*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
    (12*alpha2*int5*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
    (16*alpha2*int15*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)) + 
    (16*alpha2*CW*int16*m_Z)/(SW*(m_h2 - y23)) + 
    (2*alpha2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (alpha2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (32*alpha2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (20*alpha2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*m_h2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (12*alpha2*CW2*m_h2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (16*alpha2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) - 
    (10*alpha2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) - 
    (64*alpha2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) + 
    (40*alpha2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) - 
    (2*alpha2*int11*m_Z*SW)/(CW*CW2*y23) + (2*alpha2*int13*m_Z*SW)/(CW*CW2*y23) + 
    (2*alpha2*int20*m_Z*SW)/(CW*CW2*y23) - 
    (2*alpha2*int21*m_h2*m_Z*SW)/(CW*CW2*y23) - 
    (2*alpha2*int21*m_Z*m_Z2*SW)/(CW*CW2*y23) + 
    (2*alpha2*m_h2**2)/(CW*m_Z*SW*(m_h2 - y23)**2*y23) - 
    (32*alpha2*m_h2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2*y23) + 
    (12*alpha2*m_h2*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2*y23) + 
    (16*alpha2*int15*m_h2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)*y23) - 
    (64*alpha2*int15*m_t2**2)/(3.*CW*m_Z*SW*(m_h2 - y23)*y23) - 
    (12*alpha2*CW*int16*m_h2*m_Z)/(SW*(m_h2 - y23)*y23) + 
    (24*alpha2*CW*int16*MW2*m_Z)/(SW*(m_h2 - y23)*y23) - 
    (2*alpha2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (alpha2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (alpha2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (alpha2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (32*alpha2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (20*alpha2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (32*alpha2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (20*alpha2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (32*alpha2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (20*alpha2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*int2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*int5*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (12*alpha2*CW2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (12*alpha2*CW2*int2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (12*alpha2*CW2*int5*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (16*alpha2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) + 
    (10*alpha2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) - 
    (2*alpha2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (12*alpha2*CW2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (4*alpha2*int16*MW2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
    (24*alpha2*CW2**2*int16*m_Z*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (4*alpha2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
    (16*alpha2*CW2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (2*alpha2*int11*m_Z*m_Z2*SW)/(CW*CW2*y24**2) + 
    (2*alpha2*int21*m_Z*m_Z2**2*SW)/(CW*CW2*y24**2) - 
    (2*alpha2*int11*m_h2*m_Z*m_Z2*SW)/(CW*CW2*y23*y24**2) + 
    (2*alpha2*int20*m_h2*m_Z*m_Z2*SW)/(CW*CW2*y23*y24**2) - 
    (2*alpha2*int21*m_h2*m_Z*m_Z2**2*SW)/(CW*CW2*y23*y24**2) - 
    (2*alpha2*int11*m_Z*SW)/(CW*CW2*y24) - 
    (4*alpha2*int21*m_Z*m_Z2*SW)/(CW*CW2*y24) + 
    (2*alpha2*int11*m_h2*m_Z*SW)/(CW*CW2*y23*y24) - 
    (2*alpha2*int20*m_h2*m_Z*SW)/(CW*CW2*y23*y24) + 
    (2*alpha2*int11*m_Z*m_Z2*SW)/(CW*CW2*y23*y24) - 
    (2*alpha2*int13*m_Z*m_Z2*SW)/(CW*CW2*y23*y24) - 
    (2*alpha2*int20*m_Z*m_Z2*SW)/(CW*CW2*y23*y24) + 
    (4*alpha2*int21*m_h2*m_Z*m_Z2*SW)/(CW*CW2*y23*y24) + 
    (2*alpha2*int21*m_Z*SW*y24)/(CW*CW2*y23) + 
    (2*alpha2*int18*m_Z*m_Z2*SW)/(CW*CW2*y23*(y23 + y24)) - 
    (2*alpha2*int18*m_Z*m_Z2*SW*y23)/(CW*CW2*y24**2*(y23 + y24)) + 
    (4*alpha2*int3*m_Z*SW)/(CW*CW2*y24*(y23 + y24)) - 
    (4*alpha2*int7*m_Z*SW)/(CW*CW2*y24*(y23 + y24)) - 
    (4*alpha2*int18*m_Z*m_Z2*SW)/(CW*CW2*y24*(y23 + y24)) + 
    (2*alpha2*int18*m_Z*SW*y23)/(CW*CW2*y24*(y23 + y24)) - 
    (2*alpha2*int18*m_Z*SW*y24)/(CW*CW2*y23*(y23 + y24)))
    
    
    return a1


def coeff_a2(s, t):
    #u = (m_h**2) + (2*(m**2)) - s - t
    #beta = np.sqrt(1 - (4*((m**2)/s)))
    #costh = (((2*(m**2)) + (m_h**2) - s - (2*u)) / ((m_h**2) - s)) / beta
    #sinth = np.sqrt(1 - (costh**2))
    #y23 = (((4*s*(m_h**2)) + ((s-(m_h**2))*beta*costh*((2*(m_h*2))+(2*s))) + (((2*(m_h**4))+(2*(s**2)))*(beta**2)*(costh**2))) / (4*(m_h**2))) + ((s*(beta**2)*(sinth**2)) / 2)
    #y24 = t - (m**2)
    
    #y24 = 1653.67
    #y34 = 5647.51
    #y23 = 8323.8

    y23 = s
    y24 = t

    
    a2 = ((-2*alpha2*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) + 
    (2*alpha2*int2*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
    (2*alpha2*int5*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) + 
    (32*alpha2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) - 
    (32*alpha2*int1*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) + 
    (32*alpha2*int4*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) - 
    (12*alpha2*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) + 
    (12*alpha2*int2*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
    (12*alpha2*int5*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
    (16*alpha2*int15*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)) + 
    (16*alpha2*CW*int16*m_Z)/(SW*(m_h2 - y23)) + 
    (2*alpha2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (alpha2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (32*alpha2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (20*alpha2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*m_h2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (12*alpha2*CW2*m_h2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (16*alpha2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) - 
    (10*alpha2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) - 
    (64*alpha2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) + 
    (40*alpha2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) + 
    (2*alpha2*m_h2**2)/(CW*m_Z*SW*(m_h2 - y23)**2*y23) - 
    (32*alpha2*m_h2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2*y23) + 
    (12*alpha2*m_h2*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2*y23) + 
    (16*alpha2*int15*m_h2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)*y23) - 
    (64*alpha2*int15*m_t2**2)/(3.*CW*m_Z*SW*(m_h2 - y23)*y23) - 
    (12*alpha2*CW*int16*m_h2*m_Z)/(SW*(m_h2 - y23)*y23) + 
    (24*alpha2*CW*int16*MW2*m_Z)/(SW*(m_h2 - y23)*y23) - 
    (2*alpha2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (alpha2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (alpha2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (alpha2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (32*alpha2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (20*alpha2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (32*alpha2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (20*alpha2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (32*alpha2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (20*alpha2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*int2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*int5*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (12*alpha2*CW2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (12*alpha2*CW2*int2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (12*alpha2*CW2*int5*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (16*alpha2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) + 
    (10*alpha2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) - 
    (2*alpha2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (12*alpha2*CW2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (4*alpha2*int16*MW2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
    (24*alpha2*CW2**2*int16*m_Z*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (4*alpha2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
    (16*alpha2*CW2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (4*alpha2*int3*m_Z*SW)/(CW*CW2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
    (4*alpha2*int9*m_Z*SW)/(CW*CW2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
    (2*alpha2*int18*m_h2*m_Z*SW)/(CW*CW2*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int18*m_Z*m_Z2*SW)/(CW*CW2*(-m_h2 + y23 + y24)**2) - 
    (4*alpha2*int23*m_h2*m_Z*m_Z2*SW)/(CW*CW2*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int23*m_Z*m_Z2**2*SW)/(CW*CW2*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int23*m_h2**2*m_Z*m_Z2*SW)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int23*m_h2*m_Z*m_Z2**2*SW)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int18*m_Z*SW*y23)/(CW*CW2*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int23*m_Z*m_Z2*SW*y23)/(CW*CW2*(-m_h2 + y23 + y24)**2) + 
    (6*alpha2*int20*m_h2**2*m_Z*SW)/(CW*CW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
    (8*alpha2*int20*m_h2*m_Z*m_Z2*SW)/(CW*CW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int20*m_h2**3*m_Z*SW)/
    (CW*CW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int20*m_h2**2*m_Z*m_Z2*SW)/
    (CW*CW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
    (4*alpha2*int20*m_h2*m_Z*SW*y23)/(CW*CW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
    (4*alpha2*int20*m_Z*m_Z2*SW*y23)/(CW*CW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int13*m_Z*SW*y24)/(CW*CW2*(-m_h2 + y23 + y24)**2) + 
    (4*alpha2*int18*m_Z*SW*y24)/(CW*CW2*(-m_h2 + y23 + y24)**2) + 
    (4*alpha2*int23*m_h2*m_Z*SW*y24)/(CW*CW2*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int13*m_h2*m_Z*SW*y24)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int18*m_h2*m_Z*SW*y24)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int23*m_h2**2*m_Z*SW*y24)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int13*m_Z*m_Z2*SW*y24)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int18*m_Z*m_Z2*SW*y24)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int23*m_Z*SW*y23*y24)/(CW*CW2*(-m_h2 + y23 + y24)**2) - 
    (12*alpha2*int20*m_h2*m_Z*SW*y24)/
    (CW*CW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
    (8*alpha2*int20*m_Z*m_Z2*SW*y24)/(CW*CW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
    (6*alpha2*int20*m_h2**2*m_Z*SW*y24)/
    (CW*CW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
    (4*alpha2*int20*m_h2*m_Z*m_Z2*SW*y24)/
    (CW*CW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
    (4*alpha2*int20*m_Z*SW*y23*y24)/(CW*CW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
    (4*alpha2*int23*m_Z*SW*y24**2)/(CW*CW2*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int13*m_Z*SW*y24**2)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int18*m_Z*SW*y24**2)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) + 
    (4*alpha2*int23*m_h2*m_Z*SW*y24**2)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int23*m_Z*m_Z2*SW*y24**2)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) + 
    (6*alpha2*int20*m_Z*SW*y24**2)/(CW*CW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
    (6*alpha2*int20*m_h2*m_Z*SW*y24**2)/
    (CW*CW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int20*m_Z*m_Z2*SW*y24**2)/
    (CW*CW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int23*m_Z*SW*y24**3)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int20*m_Z*SW*y24**3)/
    (CW*CW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int11*m_Z*SW)/(CW*CW2*(-m_h2 + y23 + y24)) - 
    (2*alpha2*int11*m_h2*m_Z*SW)/(CW*CW2*y23*(-m_h2 + y23 + y24)) + 
    (2*alpha2*int11*m_Z*m_Z2*SW)/(CW*CW2*y23*(-m_h2 + y23 + y24)) + 
    (2*alpha2*int11*m_Z*SW*y24)/(CW*CW2*y23*(-m_h2 + y23 + y24)))
    return a2

def coeff_b1(s, t):
    #u = (m_h**2) + (2*(m**2)) - s - t
    #beta = np.sqrt(1 - (4*((m**2)/s)))
    #costh = (((2*(m**2)) + (m_h**2) - s - (2*u)) / ((m_h**2) - s)) / beta
    #sinth = np.sqrt(1 - (costh**2))
    #y23 = (((4*s*(m_h**2)) + ((s-(m_h**2))*beta*costh*((2*(m_h*2))+(2*s))) + (((2*(m_h**4))+(2*(s**2)))*(beta**2)*(costh**2))) / (4*(m_h**2))) + ((s*(beta**2)*(sinth**2)) / 2)
    #y24 = t - (m**2)

    #y24 = 1653.67
    #y34 = 5647.51
    #y23 = 8323.8

    y23 = s
    y24 = t

    
    b1 = ((-2*alpha2*int21*m_Z)/(CW*SW*SW2) + (alpha2*int21*m_Z)/(2.*CW*CW2*SW*SW2) + 
    (2*alpha2*CW2*int21*m_Z)/(CW*SW*SW2) + (alpha2*CW*int24*m_Z)/(SW*SW2) - 
    (2*alpha2*CW*int26*m_Z)/(SW*SW2) - (2*alpha2*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
    (2*alpha2*int5*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) + 
    (32*alpha2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) - 
    (32*alpha2*int1*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) + 
    (32*alpha2*int4*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) - 
    (4*alpha2*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
    (12*alpha2*int5*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
    (16*alpha2*int15*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)) + 
    (16*alpha2*CW*int16*m_Z)/(SW*SW2*(m_h2 - y23)) - 
    (16*alpha2*CW*CW2*int16*m_Z)/(SW*SW2*(m_h2 - y23)) + 
    (2*alpha2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (alpha2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (2.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*CW2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (12*alpha2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (10*alpha2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (32*alpha2*CW2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*m_h2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (alpha2*m_h2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (6*alpha2*CW2*m_h2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (12*alpha2*CW2**2*m_h2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*int11*m_Z)/(CW*SW*SW2*y23) - 
    (alpha2*int11*m_Z)/(2.*CW*CW2*SW*SW2*y23) - 
    (2*alpha2*CW2*int11*m_Z)/(CW*SW*SW2*y23) + 
    (alpha2*CW*int12*m_Z)/(SW*SW2*y23) - (2*alpha2*int13*m_Z)/(CW*SW*SW2*y23) + 
    (alpha2*int13*m_Z)/(2.*CW*CW2*SW*SW2*y23) + 
    (2*alpha2*CW2*int13*m_Z)/(CW*SW*SW2*y23) - 
    (alpha2*CW*int14*m_Z)/(SW*SW2*y23) + (alpha2*CW*int19*m_Z)/(SW*SW2*y23) - 
    (2*alpha2*int20*m_Z)/(CW*SW*SW2*y23) + 
    (alpha2*int20*m_Z)/(2.*CW*CW2*SW*SW2*y23) + 
    (2*alpha2*CW2*int20*m_Z)/(CW*SW*SW2*y23) + 
    (2*alpha2*int21*m_h2*m_Z)/(CW*SW*SW2*y23) - 
    (alpha2*int21*m_h2*m_Z)/(2.*CW*CW2*SW*SW2*y23) - 
    (2*alpha2*CW2*int21*m_h2*m_Z)/(CW*SW*SW2*y23) + 
    (2*alpha2*int21*m_Z*m_Z2)/(CW*SW*SW2*y23) - 
    (alpha2*int21*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y23) - 
    (2*alpha2*CW2*int21*m_Z*m_Z2)/(CW*SW*SW2*y23) - 
    (32*alpha2*m_h2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2*y23) + 
    (16*alpha2*int15*m_h2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)*y23) - 
    (64*alpha2*int15*m_t2**2)/(3.*CW*m_Z*SW*(m_h2 - y23)*y23) - 
    (12*alpha2*CW*int16*m_h2*m_Z)/(SW*SW2*(m_h2 - y23)*y23) + 
    (12*alpha2*CW*CW2*int16*m_h2*m_Z)/(SW*SW2*(m_h2 - y23)*y23) + 
    (24*alpha2*CW*int16*MW2*m_Z)/(SW*SW2*(m_h2 - y23)*y23) - 
    (24*alpha2*CW*CW2**2*int16*m_Z*m_Z2)/(SW*SW2*(m_h2 - y23)*y23) - 
    (2*alpha2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (alpha2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (2.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*CW2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (alpha2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (2.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*CW2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (alpha2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (2.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*CW2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (12*alpha2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (10*alpha2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (32*alpha2*CW2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (12*alpha2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (10*alpha2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (32*alpha2*CW2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (12*alpha2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (10*alpha2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (32*alpha2*CW2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (alpha2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*int2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (alpha2*int2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*int5*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (alpha2*int5*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (6*alpha2*CW2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (12*alpha2*CW2**2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (6*alpha2*CW2*int2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (12*alpha2*CW2**2*int2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (6*alpha2*CW2*int5*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (12*alpha2*CW2**2*int5*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (6*alpha2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (5*alpha2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (16*alpha2*CW2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (24*alpha2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
    (20*alpha2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
    (64*alpha2*CW2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
    (alpha2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (8*alpha2*CW2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
    (12*alpha2*CW2**2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (2*alpha2*int16*MW2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (4*alpha2*CW2*int16*MW2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (12*alpha2*CW2**2*int16*m_Z*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (24*alpha2*CW2**3*int16*m_Z*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (6*alpha2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (5*alpha2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (16*alpha2*CW2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (2*alpha2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (12*alpha2*CW2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (16*alpha2*CW2**2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (alpha2*CW*int12*m_h2*m_Z)/(SW*SW2*y24**2) - 
  (alpha2*CW*int12*MW2*m_Z)/(SW*SW2*y24**2) - 
  (2*alpha2*int11*m_Z*m_Z2)/(CW*SW*SW2*y24**2) + 
  (alpha2*int11*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y24**2) + 
  (2*alpha2*CW2*int11*m_Z*m_Z2)/(CW*SW*SW2*y24**2) - 
  (2*alpha2*int21*m_Z*m_Z2**2)/(CW*SW*SW2*y24**2) + 
  (alpha2*int21*m_Z*m_Z2**2)/(2.*CW*CW2*SW*SW2*y24**2) + 
  (2*alpha2*CW2*int21*m_Z*m_Z2**2)/(CW*SW*SW2*y24**2) - 
  (alpha2*CW*CW2**2*int24*m_Z*m_Z2**2)/(SW*SW2*y24**2) + 
  (alpha2*CW*int16*m_h2**2*m_Z)/(SW*SW2*(m_h2 - y23)*y24**2) + 
  (4*alpha2*CW*int16*m_h2*MW2*m_Z)/(SW*SW2*(m_h2 - y23)*y24**2) + 
  (alpha2*CW*int12*m_h2*MW2*m_Z)/(SW*SW2*y23*y24**2) + 
  (alpha2*CW*int19*m_h2*MW2*m_Z)/(SW*SW2*y23*y24**2) + 
  (2*alpha2*int11*m_h2*m_Z*m_Z2)/(CW*SW*SW2*y23*y24**2) - 
  (alpha2*int11*m_h2*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y23*y24**2) - 
  (2*alpha2*CW2*int11*m_h2*m_Z*m_Z2)/(CW*SW*SW2*y23*y24**2) - 
  (2*alpha2*int20*m_h2*m_Z*m_Z2)/(CW*SW*SW2*y23*y24**2) + 
  (alpha2*int20*m_h2*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y23*y24**2) + 
  (2*alpha2*CW2*int20*m_h2*m_Z*m_Z2)/(CW*SW*SW2*y23*y24**2) + 
  (2*alpha2*int21*m_h2*m_Z*m_Z2**2)/(CW*SW*SW2*y23*y24**2) - 
  (alpha2*int21*m_h2*m_Z*m_Z2**2)/(2.*CW*CW2*SW*SW2*y23*y24**2) - 
  (2*alpha2*CW2*int21*m_h2*m_Z*m_Z2**2)/(CW*SW*SW2*y23*y24**2) + 
  (alpha2*CW*CW2**2*int24*m_h2*m_Z*m_Z2**2)/(SW*SW2*y23*y24**2) - 
  (2*alpha2*CW*int16*m_h2**2*MW2*m_Z)/(SW*SW2*(m_h2 - y23)*y23*y24**2) - 
  (alpha2*CW*int10*m_Z*y23)/(SW*SW2*y24**2) + 
  (alpha2*CW*int12*m_Z*y23)/(SW*SW2*y24**2) - 
  (2*alpha2*CW*int16*m_h2*m_Z*y23)/(SW*SW2*(m_h2 - y23)*y24**2) - 
  (2*alpha2*CW*int16*MW2*m_Z*y23)/(SW*SW2*(m_h2 - y23)*y24**2) + 
  (alpha2*CW*int16*m_Z*y23**2)/(SW*SW2*(m_h2 - y23)*y24**2) + 
  (2*alpha2*int11*m_Z)/(CW*SW*SW2*y24) - 
  (alpha2*int11*m_Z)/(2.*CW*CW2*SW*SW2*y24) - 
  (2*alpha2*CW2*int11*m_Z)/(CW*SW*SW2*y24) + 
  (2*alpha2*CW*int12*m_Z)/(SW*SW2*y24) + 
  (2*alpha2*CW*int24*MW2*m_Z)/(SW*SW2*y24) + 
  (4*alpha2*int21*m_Z*m_Z2)/(CW*SW*SW2*y24) - 
  (alpha2*int21*m_Z*m_Z2)/(CW*CW2*SW*SW2*y24) - 
  (4*alpha2*CW2*int21*m_Z*m_Z2)/(CW*SW*SW2*y24) - 
  (4*alpha2*CW*int16*m_h2*m_Z)/(SW*SW2*(m_h2 - y23)*y24) - 
  (2*alpha2*int11*m_h2*m_Z)/(CW*SW*SW2*y23*y24) + 
  (alpha2*int11*m_h2*m_Z)/(2.*CW*CW2*SW*SW2*y23*y24) + 
  (2*alpha2*CW2*int11*m_h2*m_Z)/(CW*SW*SW2*y23*y24) - 
  (alpha2*CW*int12*m_h2*m_Z)/(SW*SW2*y23*y24) - 
  (alpha2*CW*int19*m_h2*m_Z)/(SW*SW2*y23*y24) + 
  (2*alpha2*int20*m_h2*m_Z)/(CW*SW*SW2*y23*y24) - 
  (alpha2*int20*m_h2*m_Z)/(2.*CW*CW2*SW*SW2*y23*y24) - 
  (2*alpha2*CW2*int20*m_h2*m_Z)/(CW*SW*SW2*y23*y24) - 
  (alpha2*CW*int12*MW2*m_Z)/(SW*SW2*y23*y24) + 
  (alpha2*CW*int14*MW2*m_Z)/(SW*SW2*y23*y24) - 
  (alpha2*CW*int19*MW2*m_Z)/(SW*SW2*y23*y24) - 
  (alpha2*CW*int24*m_h2*MW2*m_Z)/(SW*SW2*y23*y24) - 
  (2*alpha2*int11*m_Z*m_Z2)/(CW*SW*SW2*y23*y24) + 
  (alpha2*int11*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y23*y24) + 
  (2*alpha2*CW2*int11*m_Z*m_Z2)/(CW*SW*SW2*y23*y24) + 
  (2*alpha2*int13*m_Z*m_Z2)/(CW*SW*SW2*y23*y24) - 
  (alpha2*int13*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y23*y24) - 
  (2*alpha2*CW2*int13*m_Z*m_Z2)/(CW*SW*SW2*y23*y24) + 
  (2*alpha2*int20*m_Z*m_Z2)/(CW*SW*SW2*y23*y24) - 
  (alpha2*int20*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y23*y24) - 
  (2*alpha2*CW2*int20*m_Z*m_Z2)/(CW*SW*SW2*y23*y24) - 
  (4*alpha2*int21*m_h2*m_Z*m_Z2)/(CW*SW*SW2*y23*y24) + 
  (alpha2*int21*m_h2*m_Z*m_Z2)/(CW*CW2*SW*SW2*y23*y24) + 
  (4*alpha2*CW2*int21*m_h2*m_Z*m_Z2)/(CW*SW*SW2*y23*y24) + 
  (2*alpha2*CW*int16*m_h2**2*m_Z)/(SW*SW2*(m_h2 - y23)*y23*y24) + 
  (2*alpha2*CW*int16*m_Z*y23)/(SW*SW2*(m_h2 - y23)*y24) - 
  (2*alpha2*int21*m_Z*y24)/(CW*SW*SW2*y23) + 
  (alpha2*int21*m_Z*y24)/(2.*CW*CW2*SW*SW2*y23) + 
  (2*alpha2*CW2*int21*m_Z*y24)/(CW*SW*SW2*y23) + 
  (alpha2*CW*int17*m_Z)/(SW*SW2*(y23 + y24)) + 
  (2*alpha2*m_h2**2)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (2*alpha2*CW2*m_h2**2)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) + 
  (12*alpha2*m_h2*MW2)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (12*alpha2*CW2**2*m_h2*m_Z2)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) + 
  (alpha2*CW*int17*MW2*m_Z)/(SW*SW2*y23*(y23 + y24)) - 
  (2*alpha2*int18*m_Z*m_Z2)/(CW*SW*SW2*y23*(y23 + y24)) + 
  (alpha2*int18*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y23*(y23 + y24)) + 
  (2*alpha2*CW2*int18*m_Z*m_Z2)/(CW*SW*SW2*y23*(y23 + y24)) + 
  (2*alpha2*int2*m_h2*y23)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (2*alpha2*CW2*int2*m_h2*y23)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (8*alpha2*MW2*y23)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) + 
  (12*alpha2*int2*MW2*y23)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) + 
  (8*alpha2*CW2**2*m_Z2*y23)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (12*alpha2*CW2**2*int2*m_Z2*y23)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (alpha2*CW*int17*MW2*m_Z*y23)/(SW*SW2*y24**2*(y23 + y24)) + 
  (2*alpha2*int18*m_Z*m_Z2*y23)/(CW*SW*SW2*y24**2*(y23 + y24)) - 
  (alpha2*int18*m_Z*m_Z2*y23)/(2.*CW*CW2*SW*SW2*y24**2*(y23 + y24)) - 
  (2*alpha2*CW2*int18*m_Z*m_Z2*y23)/(CW*SW*SW2*y24**2*(y23 + y24)) + 
  (alpha2*CW*int17*m_Z*y23**2)/(SW*SW2*y24**2*(y23 + y24)) + 
  (2*alpha2*CW*m_Z)/(SW*SW2*y24*(y23 + y24)) - 
  (4*alpha2*int3*m_Z)/(CW*SW*SW2*y24*(y23 + y24)) + 
  (alpha2*int3*m_Z)/(CW*CW2*SW*SW2*y24*(y23 + y24)) + 
  (4*alpha2*CW2*int3*m_Z)/(CW*SW*SW2*y24*(y23 + y24)) - 
  (2*alpha2*CW*int6*m_Z)/(SW*SW2*y24*(y23 + y24)) + 
  (4*alpha2*int7*m_Z)/(CW*SW*SW2*y24*(y23 + y24)) - 
  (alpha2*int7*m_Z)/(CW*CW2*SW*SW2*y24*(y23 + y24)) - 
  (4*alpha2*CW2*int7*m_Z)/(CW*SW*SW2*y24*(y23 + y24)) - 
  (2*alpha2*CW*int17*MW2*m_Z)/(SW*SW2*y24*(y23 + y24)) + 
  (4*alpha2*int18*m_Z*m_Z2)/(CW*SW*SW2*y24*(y23 + y24)) - 
  (alpha2*int18*m_Z*m_Z2)/(CW*CW2*SW*SW2*y24*(y23 + y24)) - 
  (4*alpha2*CW2*int18*m_Z*m_Z2)/(CW*SW*SW2*y24*(y23 + y24)) - 
  (2*alpha2*m_h2**2*MW2)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*y24*(y23 + y24)) + 
  (2*alpha2*int2*m_h2**2*MW2)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*y24*(y23 + y24)) + 
  (3*alpha2*CW*int17*m_Z*y23)/(SW*SW2*y24*(y23 + y24)) - 
  (2*alpha2*int18*m_Z*y23)/(CW*SW*SW2*y24*(y23 + y24)) + 
  (alpha2*int18*m_Z*y23)/(2.*CW*CW2*SW*SW2*y24*(y23 + y24)) + 
  (2*alpha2*CW2*int18*m_Z*y23)/(CW*SW*SW2*y24*(y23 + y24)) + 
  (4*alpha2*m_h2*MW2*y23)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*y24*(y23 + y24)) - 
  (4*alpha2*int2*m_h2*MW2*y23)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*y24*(y23 + y24)) - 
  (2*alpha2*MW2*y23**2)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*y24*(y23 + y24)) + 
  (2*alpha2*int2*MW2*y23**2)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*y24*(y23 + y24)) + 
  (2*alpha2*int2*m_h2*y24)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (2*alpha2*CW2*int2*m_h2*y24)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (8*alpha2*MW2*y24)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) + 
  (12*alpha2*int2*MW2*y24)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) + 
  (8*alpha2*CW2**2*m_Z2*y24)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (12*alpha2*CW2**2*int2*m_Z2*y24)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (alpha2*CW*int17*m_Z*y24)/(SW*SW2*y23*(y23 + y24)) + 
  (2*alpha2*int18*m_Z*y24)/(CW*SW*SW2*y23*(y23 + y24)) - 
  (alpha2*int18*m_Z*y24)/(2.*CW*CW2*SW*SW2*y23*(y23 + y24)) - 
  (2*alpha2*CW2*int18*m_Z*y24)/(CW*SW*SW2*y23*(y23 + y24)) + 
  (2*alpha2*m_h2**2*y24)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(y23 + y24)) - 
  (2*alpha2*CW2*m_h2**2*y24)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(y23 + y24)) + 
  (12*alpha2*m_h2*MW2*y24)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(y23 + y24)) - 
  (12*alpha2*CW2**2*m_h2*m_Z2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(y23 + y24)) + 
  (2*alpha2*CW*int22*m_h2*m_Z)/(SW*SW2*(-m_h2 + y23 + y24)) + 
  (4*alpha2*CW*int22*MW2*m_Z)/(SW*SW2*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*int22*m_h2*MW2*m_Z)/(SW*SW2*y23*(-m_h2 + y23 + y24)) - 
  (3*alpha2*CW*int22*m_Z*y23)/(SW*SW2*(-m_h2 + y23 + y24)) + 
  (2*alpha2*CW*int22*m_h2**2*MW2*m_Z)/(SW*SW2*y24**2*(-m_h2 + y23 + y24)) + 
  (2*alpha2*CW*CW2**2*int22*m_h2*m_Z*m_Z2**2)/
   (SW*SW2*y24**2*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*CW2**2*int22*m_h2**2*m_Z*m_Z2**2)/
   (SW*SW2*y23*y24**2*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*int22*m_h2**2*m_Z*y23)/(SW*SW2*y24**2*(-m_h2 + y23 + y24)) - 
  (4*alpha2*CW*int22*m_h2*MW2*m_Z*y23)/(SW*SW2*y24**2*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*CW2**2*int22*m_Z*m_Z2**2*y23)/(SW*SW2*y24**2*(-m_h2 + y23 + y24)) + 
  (2*alpha2*CW*int22*m_h2*m_Z*y23**2)/(SW*SW2*y24**2*(-m_h2 + y23 + y24)) + 
  (2*alpha2*CW*int22*MW2*m_Z*y23**2)/(SW*SW2*y24**2*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*int22*m_Z*y23**3)/(SW*SW2*y24**2*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*int22*m_h2**2*m_Z)/(SW*SW2*y24*(-m_h2 + y23 + y24)) - 
  (7*alpha2*CW*int22*m_h2*MW2*m_Z)/(SW*SW2*y24*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*CW2**2*int22*m_Z*m_Z2**2)/(SW*SW2*y24*(-m_h2 + y23 + y24)) + 
  (alpha2*CW*int22*m_h2**2*MW2*m_Z)/(SW*SW2*y23*y24*(-m_h2 + y23 + y24)) + 
  (alpha2*CW*CW2**2*int22*m_h2*m_Z*m_Z2**2)/
   (SW*SW2*y23*y24*(-m_h2 + y23 + y24)) + 
  (4*alpha2*CW*int22*m_h2*m_Z*y23)/(SW*SW2*y24*(-m_h2 + y23 + y24)) + 
  (6*alpha2*CW*int22*MW2*m_Z*y23)/(SW*SW2*y24*(-m_h2 + y23 + y24)) - 
  (3*alpha2*CW*int22*m_Z*y23**2)/(SW*SW2*y24*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*int22*m_Z*y24)/(SW*SW2*(-m_h2 + y23 + y24)))
    return b1

def coeff_b2(s, t):
    #u = (m_h**2) + (2*(m**2)) - s - t
    #beta = np.sqrt(1 - (4*((m**2)/s)))
    #costh = (((2*(m**2)) + (m_h**2) - s - (2*u)) / ((m_h**2) - s)) / beta
    #sinth = np.sqrt(1 - (costh**2))
    #y23 = (((4*s*(m_h**2)) + ((s-(m_h**2))*beta*costh*((2*(m_h*2))+(2*s))) + (((2*(m_h**4))+(2*(s**2)))*(beta**2)*(costh**2))) / (4*(m_h**2))) + ((s*(beta**2)*(sinth**2)) / 2)
    #y24 = t - (m**2)

    #y23 = 8323.8
    #y24 = 1653.67
    #y34 =  5647.51

    y23 = s
    y24 = t


        
    b2 = ((-2*alpha2*CW*int25*m_Z)/(SW*SW2) - (2*alpha2*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
  (2*alpha2*int5*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) + 
  (32*alpha2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) - 
  (32*alpha2*int1*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) + 
  (32*alpha2*int4*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) - 
  (4*alpha2*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
  (12*alpha2*int5*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
  (16*alpha2*int15*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)) + 
  (2*alpha2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (alpha2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (2.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (2*alpha2*CW2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (12*alpha2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (10*alpha2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (32*alpha2*CW2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (2*alpha2*m_h2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (alpha2*m_h2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (6*alpha2*CW2*m_h2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (12*alpha2*CW2**2*m_h2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (32*alpha2*m_h2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2*y23) + 
  (16*alpha2*int15*m_h2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)*y23) - 
  (64*alpha2*int15*m_t2**2)/(3.*CW*m_Z*SW*(m_h2 - y23)*y23) - 
  (2*alpha2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (alpha2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (2.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (2*alpha2*CW2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (2*alpha2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (alpha2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (2.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (2*alpha2*CW2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (2*alpha2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (alpha2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (2.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (2*alpha2*CW2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (12*alpha2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (10*alpha2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (32*alpha2*CW2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (12*alpha2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (10*alpha2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (32*alpha2*CW2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (12*alpha2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (10*alpha2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (32*alpha2*CW2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (2*alpha2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (alpha2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (2*alpha2*int2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (alpha2*int2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (2*alpha2*int5*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (alpha2*int5*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (6*alpha2*CW2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (12*alpha2*CW2**2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (6*alpha2*CW2*int2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (12*alpha2*CW2**2*int2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (6*alpha2*CW2*int5*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (12*alpha2*CW2**2*int5*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (6*alpha2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (5*alpha2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (16*alpha2*CW2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (24*alpha2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (20*alpha2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (64*alpha2*CW2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (alpha2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (8*alpha2*CW2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (12*alpha2*CW2**2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (2*alpha2*int16*MW2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (4*alpha2*CW2*int16*MW2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (12*alpha2*CW2**2*int16*m_Z*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (24*alpha2*CW2**3*int16*m_Z*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (6*alpha2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (5*alpha2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (16*alpha2*CW2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (2*alpha2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (12*alpha2*CW2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (16*alpha2*CW2**2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (alpha2*CW*int17*m_h2*m_Z)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int22*m_h2**2*m_Z)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int17*MW2*m_Z)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (3*alpha2*CW*int22*m_h2*MW2*m_Z)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (3*alpha2*CW*int24*m_h2*MW2*m_Z)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (alpha2*CW*CW2**2*int22*m_Z*m_Z2**2)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (alpha2*CW*CW2**2*int24*m_Z*m_Z2**2)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (35*alpha2*CW*int16*m_h2**2*m_Z)/(SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (40*alpha2*CW*CW2*int16*m_h2**2*m_Z)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (44*alpha2*CW*CW2*int16*m_h2*m_Z*m_Z2)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) + 
  (48*alpha2*CW*CW2**2*int16*m_h2*m_Z*m_Z2)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (alpha2*CW*int22*m_h2**2*MW2*m_Z)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) - 
  (alpha2*CW*int24*m_h2**2*MW2*m_Z)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*CW2**2*int22*m_h2*m_Z*m_Z2**2)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*CW2**2*int24*m_h2*m_Z*m_Z2**2)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) - 
  (10*alpha2*CW*int16*m_h2**3*m_Z)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) + 
  (12*alpha2*CW*CW2*int16*m_h2**3*m_Z)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) + 
  (22*alpha2*CW*CW2*int16*m_h2**2*m_Z*m_Z2)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) - 
  (24*alpha2*CW*CW2**2*int16*m_h2**2*m_Z*m_Z2)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) - 
  (alpha2*CW*int10*m_Z*y23)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int17*m_Z*y23)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW*int22*m_h2*m_Z*y23)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW*int22*MW2*m_Z*y23)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW*int24*MW2*m_Z*y23)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (40*alpha2*CW*int16*m_h2*m_Z*y23)/(SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) + 
  (44*alpha2*CW*CW2*int16*m_h2*m_Z*y23)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) + 
  (22*alpha2*CW*CW2*int16*m_Z*m_Z2*y23)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (24*alpha2*CW*CW2**2*int16*m_Z*m_Z2*y23)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int22*m_Z*y23**2)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (15*alpha2*CW*int16*m_Z*y23**2)/(SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (16*alpha2*CW*CW2*int16*m_Z*y23**2)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) + 
  (4*alpha2*CW*int19*m_h2**2*m_Z)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)**2) - 
  (4*alpha2*CW*int19*m_h2*MW2*m_Z)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)**2) - 
  (alpha2*CW*int19*m_h2**3*m_Z)/(SW*SW2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int19*m_h2**2*MW2*m_Z)/
   (SW*SW2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW*int19*m_h2*m_Z*y23)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*CW*int19*MW2*m_Z*y23)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*CW*m_Z)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (4*alpha2*int3*m_Z)/(CW*SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (alpha2*int3*m_Z)/(CW*CW2*SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (4*alpha2*CW2*int3*m_Z)/(CW*SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*CW*int8*m_Z)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (4*alpha2*int9*m_Z)/(CW*SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (alpha2*int9*m_Z)/(CW*CW2*SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (4*alpha2*CW2*int9*m_Z)/(CW*SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*m_h2**3)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (2*alpha2*CW2*m_h2**3)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (2*alpha2*int2*m_h2**3)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*CW2*int2*m_h2**3)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (22*alpha2*CW2*m_h2**2*m_Z2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (20*alpha2*CW2**2*m_h2**2*m_Z2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (14*alpha2*CW2*int2*m_h2**2*m_Z2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (12*alpha2*CW2**2*int2*m_h2**2*m_Z2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (2*alpha2*m_h2**4)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*CW2*m_h2**4)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (12*alpha2*CW2*m_h2**3*m_Z2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (12*alpha2*CW2**2*m_h2**3*m_Z2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*int2*m_h2**2*y23)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (2*alpha2*CW2*int2*m_h2**2*y23)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (12*alpha2*CW2*m_h2*m_Z2*y23)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (8*alpha2*CW2**2*m_h2*m_Z2*y23)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (16*alpha2*CW2*int2*m_h2*m_Z2*y23)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (12*alpha2*CW2**2*int2*m_h2*m_Z2*y23)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*CW2*m_Z2*y23**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (2*alpha2*CW2*int2*m_Z2*y23**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (2*alpha2*int13*m_Z*y24)/(CW*SW*SW2*(m_h2 - y23 - y24)**2) - 
  (alpha2*int13*m_Z*y24)/(2.*CW*CW2*SW*SW2*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW2*int13*m_Z*y24)/(CW*SW*SW2*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*CW*int17*m_Z*y24)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW*int22*m_h2*m_Z*y24)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int24*m_h2*m_Z*y24)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW*int22*MW2*m_Z*y24)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (4*alpha2*CW*int24*MW2*m_Z*y24)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (52*alpha2*CW*int16*m_h2*m_Z*y24)/(SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) + 
  (56*alpha2*CW*CW2*int16*m_h2*m_Z*y24)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) + 
  (48*alpha2*CW*CW2*int16*m_Z*m_Z2*y24)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (48*alpha2*CW*CW2**2*int16*m_Z*m_Z2*y24)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*int13*m_h2*m_Z*y24)/(CW*SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (alpha2*int13*m_h2*m_Z*y24)/(2.*CW*CW2*SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*CW2*int13*m_h2*m_Z*y24)/(CW*SW*SW2*y23*(m_h2 - y23 - y24)**2) - 
  (alpha2*CW*int14*m_h2*m_Z*y24)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) - 
  (alpha2*CW*int17*m_h2*m_Z*y24)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int14*MW2*m_Z*y24)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int17*MW2*m_Z*y24)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int22*m_h2*MW2*m_Z*y24)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int24*m_h2*MW2*m_Z*y24)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*int13*m_Z*m_Z2*y24)/(CW*SW*SW2*y23*(m_h2 - y23 - y24)**2) - 
  (alpha2*int13*m_Z*m_Z2*y24)/(2.*CW*CW2*SW*SW2*y23*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW2*int13*m_Z*m_Z2*y24)/(CW*SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (22*alpha2*CW*int16*m_h2**2*m_Z*y24)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) - 
  (24*alpha2*CW*CW2*int16*m_h2**2*m_Z*y24)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) - 
  (48*alpha2*CW*CW2*int16*m_h2*m_Z*m_Z2*y24)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) + 
  (48*alpha2*CW*CW2**2*int16*m_h2*m_Z*m_Z2*y24)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*CW*int22*m_Z*y23*y24)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (30*alpha2*CW*int16*m_Z*y23*y24)/(SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (32*alpha2*CW*CW2*int16*m_Z*y23*y24)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (8*alpha2*CW*int19*m_h2*m_Z*y24)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (4*alpha2*CW*int19*MW2*m_Z*y24)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (3*alpha2*CW*int19*m_h2**2*m_Z*y24)/
   (SW*SW2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW*int19*m_h2*MW2*m_Z*y24)/
   (SW*SW2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*CW*int19*m_Z*y23*y24)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*m_h2**2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*CW2*m_h2**2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (4*alpha2*int2*m_h2**2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (4*alpha2*CW2*int2*m_h2**2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (28*alpha2*CW2*m_h2*m_Z2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (28*alpha2*CW2**2*m_h2*m_Z2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (24*alpha2*CW2*int2*m_h2*m_Z2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (24*alpha2*CW2**2*int2*m_h2*m_Z2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (4*alpha2*m_h2**3*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (4*alpha2*CW2*m_h2**3*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (24*alpha2*CW2*m_h2**2*m_Z2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (24*alpha2*CW2**2*m_h2**2*m_Z2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (2*alpha2*int2*m_h2*y23*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*CW2*int2*m_h2*y23*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (8*alpha2*CW2*m_Z2*y23*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (8*alpha2*CW2**2*m_Z2*y23*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (12*alpha2*CW2*int2*m_Z2*y23*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (12*alpha2*CW2**2*int2*m_Z2*y23*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (alpha2*CW*int22*m_Z*y24**2)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (alpha2*CW*int24*m_Z*y24**2)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (16*alpha2*CW*int16*m_Z*y24**2)/(SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (16*alpha2*CW*CW2*int16*m_Z*y24**2)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*int13*m_Z*y24**2)/(CW*SW*SW2*y23*(m_h2 - y23 - y24)**2) - 
  (alpha2*int13*m_Z*y24**2)/(2.*CW*CW2*SW*SW2*y23*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW2*int13*m_Z*y24**2)/(CW*SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int14*m_Z*y24**2)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int17*m_Z*y24**2)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) - 
  (12*alpha2*CW*int16*m_h2*m_Z*y24**2)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) + 
  (12*alpha2*CW*CW2*int16*m_h2*m_Z*y24**2)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) + 
  (24*alpha2*CW*CW2*int16*m_Z*m_Z2*y24**2)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) - 
  (24*alpha2*CW*CW2**2*int16*m_Z*m_Z2*y24**2)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) + 
  (4*alpha2*CW*int19*m_Z*y24**2)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)**2) - 
  (3*alpha2*CW*int19*m_h2*m_Z*y24**2)/
   (SW*SW2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int19*MW2*m_Z*y24**2)/
   (SW*SW2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*int2*m_h2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*CW2*int2*m_h2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (8*alpha2*CW2*m_Z2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (8*alpha2*CW2**2*m_Z2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (12*alpha2*CW2*int2*m_Z2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (12*alpha2*CW2**2*int2*m_Z2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (2*alpha2*m_h2**2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*CW2*m_h2**2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (12*alpha2*CW2*m_h2*m_Z2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (12*alpha2*CW2**2*m_h2*m_Z2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (alpha2*CW*int19*m_Z*y24**3)/(SW*SW2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*int18*m_h2*m_Z)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int18*m_h2*m_Z)/(2.*CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*CW2*int18*m_h2*m_Z)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int18*m_Z*m_Z2)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int18*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int18*m_Z*m_Z2)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (4*alpha2*int23*m_h2*m_Z*m_Z2)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int23*m_h2*m_Z*m_Z2)/(CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (4*alpha2*CW2*int23*m_h2*m_Z*m_Z2)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int23*m_Z*m_Z2**2)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int23*m_Z*m_Z2**2)/(2.*CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int23*m_Z*m_Z2**2)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int23*m_h2**2*m_Z*m_Z2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int23*m_h2**2*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int23*m_h2**2*m_Z*m_Z2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*int23*m_h2*m_Z*m_Z2**2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int23*m_h2*m_Z*m_Z2**2)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*CW2*int23*m_h2*m_Z*m_Z2**2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int18*m_Z*y23)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int18*m_Z*y23)/(2.*CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int18*m_Z*y23)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int23*m_Z*m_Z2*y23)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int23*m_Z*m_Z2*y23)/(2.*CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int23*m_Z*m_Z2*y23)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (6*alpha2*int20*m_h2**2*m_Z)/(CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (3*alpha2*int20*m_h2**2*m_Z)/
   (2.*CW*CW2*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (6*alpha2*CW2*int20*m_h2**2*m_Z)/
   (CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (8*alpha2*int20*m_h2*m_Z*m_Z2)/(CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int20*m_h2*m_Z*m_Z2)/
   (CW*CW2*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (8*alpha2*CW2*int20*m_h2*m_Z*m_Z2)/
   (CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*int20*m_h2**3*m_Z)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int20*m_h2**3*m_Z)/
   (2.*CW*CW2*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*CW2*int20*m_h2**3*m_Z)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int20*m_h2**2*m_Z*m_Z2)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int20*m_h2**2*m_Z*m_Z2)/
   (2.*CW*CW2*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int20*m_h2**2*m_Z*m_Z2)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (4*alpha2*int20*m_h2*m_Z*y23)/(CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int20*m_h2*m_Z*y23)/
   (CW*CW2*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (4*alpha2*CW2*int20*m_h2*m_Z*y23)/
   (CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (4*alpha2*int20*m_Z*m_Z2*y23)/(CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int20*m_Z*m_Z2*y23)/
   (CW*CW2*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (4*alpha2*CW2*int20*m_Z*m_Z2*y23)/
   (CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (4*alpha2*int18*m_Z*y24)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int18*m_Z*y24)/(CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (4*alpha2*CW2*int18*m_Z*y24)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (4*alpha2*int23*m_h2*m_Z*y24)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int23*m_h2*m_Z*y24)/(CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (4*alpha2*CW2*int23*m_h2*m_Z*y24)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*int18*m_h2*m_Z*y24)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int18*m_h2*m_Z*y24)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*CW2*int18*m_h2*m_Z*y24)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*int23*m_h2**2*m_Z*y24)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int23*m_h2**2*m_Z*y24)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*CW2*int23*m_h2**2*m_Z*y24)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int18*m_Z*m_Z2*y24)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int18*m_Z*m_Z2*y24)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int18*m_Z*m_Z2*y24)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*int23*m_Z*y23*y24)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int23*m_Z*y23*y24)/(2.*CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*CW2*int23*m_Z*y23*y24)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (12*alpha2*int20*m_h2*m_Z*y24)/
   (CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (3*alpha2*int20*m_h2*m_Z*y24)/
   (CW*CW2*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (12*alpha2*CW2*int20*m_h2*m_Z*y24)/
   (CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (8*alpha2*int20*m_Z*m_Z2*y24)/(CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*int20*m_Z*m_Z2*y24)/
   (CW*CW2*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (8*alpha2*CW2*int20*m_Z*m_Z2*y24)/
   (CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (6*alpha2*int20*m_h2**2*m_Z*y24)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (3*alpha2*int20*m_h2**2*m_Z*y24)/
   (2.*CW*CW2*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (6*alpha2*CW2*int20*m_h2**2*m_Z*y24)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (4*alpha2*int20*m_h2*m_Z*m_Z2*y24)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int20*m_h2*m_Z*m_Z2*y24)/
   (CW*CW2*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (4*alpha2*CW2*int20*m_h2*m_Z*m_Z2*y24)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (4*alpha2*int20*m_Z*y23*y24)/(CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int20*m_Z*y23*y24)/
   (CW*CW2*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (4*alpha2*CW2*int20*m_Z*y23*y24)/
   (CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (4*alpha2*int23*m_Z*y24**2)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int23*m_Z*y24**2)/(CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (4*alpha2*CW2*int23*m_Z*y24**2)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int18*m_Z*y24**2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int18*m_Z*y24**2)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int18*m_Z*y24**2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (4*alpha2*int23*m_h2*m_Z*y24**2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int23*m_h2*m_Z*y24**2)/(CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (4*alpha2*CW2*int23*m_h2*m_Z*y24**2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*int23*m_Z*m_Z2*y24**2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int23*m_Z*m_Z2*y24**2)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*CW2*int23*m_Z*m_Z2*y24**2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (6*alpha2*int20*m_Z*y24**2)/(CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (3*alpha2*int20*m_Z*y24**2)/
   (2.*CW*CW2*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (6*alpha2*CW2*int20*m_Z*y24**2)/
   (CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (6*alpha2*int20*m_h2*m_Z*y24**2)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (3*alpha2*int20*m_h2*m_Z*y24**2)/
   (2.*CW*CW2*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (6*alpha2*CW2*int20*m_h2*m_Z*y24**2)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int20*m_Z*m_Z2*y24**2)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int20*m_Z*m_Z2*y24**2)/
   (2.*CW*CW2*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int20*m_Z*m_Z2*y24**2)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*int23*m_Z*y24**3)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int23*m_Z*y24**3)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*CW2*int23*m_Z*y24**3)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int20*m_Z*y24**3)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int20*m_Z*y24**3)/
   (2.*CW*CW2*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int20*m_Z*y24**3)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int11*m_Z)/(CW*SW*SW2*(-m_h2 + y23 + y24)) + 
  (alpha2*int11*m_Z)/(2.*CW*CW2*SW*SW2*(-m_h2 + y23 + y24)) + 
  (2*alpha2*CW2*int11*m_Z)/(CW*SW*SW2*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*int12*m_Z)/(SW*SW2*(-m_h2 + y23 + y24)) + 
  (2*alpha2*int11*m_h2*m_Z)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)) - 
  (alpha2*int11*m_h2*m_Z)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)) - 
  (2*alpha2*CW2*int11*m_h2*m_Z)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)) + 
  (alpha2*CW*int12*m_h2*m_Z)/(SW*SW2*y23*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*int12*MW2*m_Z)/(SW*SW2*y23*(-m_h2 + y23 + y24)) - 
  (2*alpha2*int11*m_Z*m_Z2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)) + 
  (alpha2*int11*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)) + 
  (2*alpha2*CW2*int11*m_Z*m_Z2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)) - 
  (2*alpha2*int11*m_Z*y24)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)) + 
  (alpha2*int11*m_Z*y24)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)) + 
  (2*alpha2*CW2*int11*m_Z*y24)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*int12*m_Z*y24)/(SW*SW2*y23*(-m_h2 + y23 + y24)))
    return b2


def loop_decay_mason(x):
    s = x[0]
    b = (m**2) + ((((m_h**2) - (s)) / 2) * (1 + np.sqrt(1 - ((4 * (m**2)) / (s)))))
    a = (m**2) + ((((m_h**2) - (s)) / 2) * (1 - np.sqrt(1 - ((4 * (m**2)) / (s)))))
    difference = b - a   
    t = (x[1] * (b-a)) + a
    u = (m_h**2) + (2*(m**2)) - s - t
    prefac = 1 / (512*(np.pi**3)*(m_h**3))
    
    y23 = s
    y24 = t

       
    a_1 = abs(coeff_a1(s, t))**2
    a_2 = abs(coeff_a2(s, t))**2
    b_1 = abs(coeff_b1(s, t))**2
    b_2 = abs(coeff_b2(s, t))**2

    return prefac * s * (((t**2)*(a_1 + b_1)) + ((u**2)*(a_2 + b_2)))

nbins = 100

def loop_decay(x):
    
    s_min_fix = 4 * m ** 2 #* (1.0001)
    s_max_fix = (m_h ** 2) - (10*m_h)
    s = (s_max_fix- s_min_fix) * x[0] + s_min_fix
    t_min = 0.5 * (m_h2 - s + 2 * m ** 2 - (m_h2 - s) * np.sqrt(1 - 4 * m ** 2 / s) )
    t_max = 0.5 * (m_h2 - s + 2 * m ** 2 + (m_h2 - s) * np.sqrt(1 - 4 * m ** 2 / s) )
    t = (t_max - t_min) * x[1] + t_min
    
    jac = (s_max_fix - s_min_fix) * (t_max - t_min)
    
    y23 = s
    y24 = t

    u = m_h ** 2 + 2 * m ** 2 - s - t
    prefac = jac / (512 * np.pi ** 3 * m_h ** 3)

    p1 = [m_h2]
    m1 = [m_t2,m_t2]
    int1 = td.integral(mu2,m1,p1)[0]

    p2 = [m_h2]
    m2 = [MW2, MW2]
    int2 = td.integral(mu2,m2,p2)[0]

    p3 = [m_h2]
    m3 = [m_Z2, m_Z2]
    int3 = td.integral(mu2,m3,p3)[0]

    p4 = [y23]
    m4 = [m_t2, m_t2]
    int4 = td.integral(mu2,m4,p4)[0]

    p5 = [y23]
    m5 = [MW2, MW2]
    int5 = td.integral(mu2,m5,p5)[0]

    p6 = [m_h2 - y23 - y24]
    m6 = [0, MW2]
    int6 = td.integral(mu2,m6,p6)[0]

    p7 = [m_h2 - y23 - y24]
    m7 = [0, m_Z2]
    int7 = td.integral(mu2,m7,p7)[0]

    p8 = [y24]
    m8 = [0, MW2]
    int8 = td.integral(mu2,m8,p8)[0]

    p9 = [y24]
    m9 = [0, m_Z2]
    int9 = td.integral(mu2,m9,p9)[0]

    p10 = [0,0,y23]
    m10 = [MW2,0, MW2]
    int10 = td.integral(mu2,m10,p10)[0]

    p11 = [0,0,  m_h2-y23-y24]
    m11 = [0, 0,  m_Z2]
    int11 = td.integral(mu2,m11,p11)[0]

    p12 = [0,0,m_h2-y23-y24]
    m12 = [0, MW2,MW2]
    int12 = td.integral(mu2,m12,p12)[0]

    p13 = [0,0,y24]
    m13 = [0, 0 ,m_Z2]
    int13 = td.integral(mu2,m13,p13)[0]

    p14 = [0,0,y24]
    m14 = [0, MW2 ,MW2]
    int14 = td.integral(mu2,m14,p14)[0]

    p15 = [0,m_h2,y23]
    m15 = [m_t2, m_t2 ,m_t2]
    int15 = td.integral(mu2,m15,p15)[0]

    p16 = [0,m_h2,y23]
    m16 = [MW2, MW2 ,MW2]
    int16 = td.integral(mu2,m16,p16)[0]

    p17 = [0,m_h2, m_h2 - y23 - y24]
    m17 = [0, MW2 ,MW2]
    int17 = td.integral(mu2,m17,p17)[0]

    p18 = [0, m_h2, m_h2 - y23 - y24]
    m18 = [0, m_Z2 ,m_Z2]
    int18 = td.integral(mu2,m18,p18)[0]

    p19 = [0, m_h2, y24]
    m19 = [0, MW2 ,MW2]
    int19 = td.integral(mu2,m19,p19)[0]

    p20 = [0, m_h2,y24]
    m20 = [0, m_Z2 ,m_Z2]
    int20 = td.integral(mu2,m20,p20)[0]
   
    p21 = [0,  m_h2 , 0, 0, y24,m_h2 - y23 -y24]
    m21 = [0, m_Z2, m_Z2 ,0]
    int21 = td.integral(mu2,m21,p21)[0]

    p22 = [0,  m_h2 - y23 - y24, m_h2, y23, 0,0]
    m22 = [MW2, 0, MW2 ,MW2]
    int22 = td.integral(mu2,m22,p22)[0]

    #should be 0,m_h2 not m_Z2,m_h2 at end                                                                                     
    p23 = [0, y24, 0, m_h2-y23-y24, 0.001, m_h2]
    m23 = [0, m_Z2, 0 ,m_Z2]
    int23 = td.integral(mu2,m23,p23)[0]
    ###actually int23 = int21 so just use that fact                                                                         
    int23 = int21

    p24 = [0, y24, m_h2,y23, 0, 0]
    m24 = [MW2, 0, MW2 , MW2]
    int24 = td.integral(mu2,m24,p24)[0]

    p25 = [m_h2, 0, 0,0, y23, m_h2-y23-y24]
    m25 = [MW2, MW2, MW2 , 0]
    int25 = td.integral(mu2,m25,p25)[0]

    p26 = [m_h2, 0, 0,0, y23, y24]
    m26 = [MW2, MW2, MW2 , 0]
    int26 = td.integral(mu2,m26,p26)[0]

    a1 = ((2*alpha2*int21*m_Z*SW)/(CW*CW2) - (2*alpha2*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) + 
    (2*alpha2*int2*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
    (2*alpha2*int5*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) + 
    (32*alpha2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) - 
    (32*alpha2*int1*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) + 
    (32*alpha2*int4*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) - 
    (12*alpha2*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) + 
    (12*alpha2*int2*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
    (12*alpha2*int5*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
    (16*alpha2*int15*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)) + 
    (16*alpha2*CW*int16*m_Z)/(SW*(m_h2 - y23)) + 
    (2*alpha2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (alpha2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (32*alpha2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (20*alpha2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*m_h2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (12*alpha2*CW2*m_h2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (16*alpha2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) - 
    (10*alpha2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) - 
    (64*alpha2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) + 
    (40*alpha2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) - 
    (2*alpha2*int11*m_Z*SW)/(CW*CW2*y23) + (2*alpha2*int13*m_Z*SW)/(CW*CW2*y23) + 
    (2*alpha2*int20*m_Z*SW)/(CW*CW2*y23) - 
    (2*alpha2*int21*m_h2*m_Z*SW)/(CW*CW2*y23) - 
    (2*alpha2*int21*m_Z*m_Z2*SW)/(CW*CW2*y23) + 
    (2*alpha2*m_h2**2)/(CW*m_Z*SW*(m_h2 - y23)**2*y23) - 
    (32*alpha2*m_h2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2*y23) + 
    (12*alpha2*m_h2*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2*y23) + 
    (16*alpha2*int15*m_h2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)*y23) - 
    (64*alpha2*int15*m_t2**2)/(3.*CW*m_Z*SW*(m_h2 - y23)*y23) - 
    (12*alpha2*CW*int16*m_h2*m_Z)/(SW*(m_h2 - y23)*y23) + 
    (24*alpha2*CW*int16*MW2*m_Z)/(SW*(m_h2 - y23)*y23) - 
    (2*alpha2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (alpha2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (alpha2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (alpha2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (32*alpha2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (20*alpha2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (32*alpha2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (20*alpha2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (32*alpha2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (20*alpha2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*int2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*int5*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (12*alpha2*CW2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (12*alpha2*CW2*int2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (12*alpha2*CW2*int5*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (16*alpha2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) + 
    (10*alpha2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) - 
    (2*alpha2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (12*alpha2*CW2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (4*alpha2*int16*MW2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
    (24*alpha2*CW2**2*int16*m_Z*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (4*alpha2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
    (16*alpha2*CW2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (2*alpha2*int11*m_Z*m_Z2*SW)/(CW*CW2*y24**2) + 
    (2*alpha2*int21*m_Z*m_Z2**2*SW)/(CW*CW2*y24**2) - 
    (2*alpha2*int11*m_h2*m_Z*m_Z2*SW)/(CW*CW2*y23*y24**2) + 
    (2*alpha2*int20*m_h2*m_Z*m_Z2*SW)/(CW*CW2*y23*y24**2) - 
    (2*alpha2*int21*m_h2*m_Z*m_Z2**2*SW)/(CW*CW2*y23*y24**2) - 
    (2*alpha2*int11*m_Z*SW)/(CW*CW2*y24) - 
    (4*alpha2*int21*m_Z*m_Z2*SW)/(CW*CW2*y24) + 
    (2*alpha2*int11*m_h2*m_Z*SW)/(CW*CW2*y23*y24) - 
    (2*alpha2*int20*m_h2*m_Z*SW)/(CW*CW2*y23*y24) + 
    (2*alpha2*int11*m_Z*m_Z2*SW)/(CW*CW2*y23*y24) - 
    (2*alpha2*int13*m_Z*m_Z2*SW)/(CW*CW2*y23*y24) - 
    (2*alpha2*int20*m_Z*m_Z2*SW)/(CW*CW2*y23*y24) + 
    (4*alpha2*int21*m_h2*m_Z*m_Z2*SW)/(CW*CW2*y23*y24) + 
    (2*alpha2*int21*m_Z*SW*y24)/(CW*CW2*y23) + 
    (2*alpha2*int18*m_Z*m_Z2*SW)/(CW*CW2*y23*(y23 + y24)) - 
    (2*alpha2*int18*m_Z*m_Z2*SW*y23)/(CW*CW2*y24**2*(y23 + y24)) + 
    (4*alpha2*int3*m_Z*SW)/(CW*CW2*y24*(y23 + y24)) - 
    (4*alpha2*int7*m_Z*SW)/(CW*CW2*y24*(y23 + y24)) - 
    (4*alpha2*int18*m_Z*m_Z2*SW)/(CW*CW2*y24*(y23 + y24)) + 
    (2*alpha2*int18*m_Z*SW*y23)/(CW*CW2*y24*(y23 + y24)) - 
    (2*alpha2*int18*m_Z*SW*y24)/(CW*CW2*y23*(y23 + y24)))




    a2 = ((-2*alpha2*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) + 
    (2*alpha2*int2*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
    (2*alpha2*int5*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) + 
    (32*alpha2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) - 
    (32*alpha2*int1*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) + 
    (32*alpha2*int4*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) - 
    (12*alpha2*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) + 
    (12*alpha2*int2*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
    (12*alpha2*int5*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
    (16*alpha2*int15*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)) + 
    (16*alpha2*CW*int16*m_Z)/(SW*(m_h2 - y23)) + 
    (2*alpha2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (alpha2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (32*alpha2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (20*alpha2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*m_h2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (12*alpha2*CW2*m_h2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (16*alpha2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) - 
    (10*alpha2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) - 
    (64*alpha2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) + 
    (40*alpha2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) + 
    (2*alpha2*m_h2**2)/(CW*m_Z*SW*(m_h2 - y23)**2*y23) - 
    (32*alpha2*m_h2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2*y23) + 
    (12*alpha2*m_h2*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2*y23) + 
    (16*alpha2*int15*m_h2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)*y23) - 
    (64*alpha2*int15*m_t2**2)/(3.*CW*m_Z*SW*(m_h2 - y23)*y23) - 
    (12*alpha2*CW*int16*m_h2*m_Z)/(SW*(m_h2 - y23)*y23) + 
    (24*alpha2*CW*int16*MW2*m_Z)/(SW*(m_h2 - y23)*y23) - 
    (2*alpha2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (alpha2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (alpha2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (alpha2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (32*alpha2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (20*alpha2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (32*alpha2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (20*alpha2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (32*alpha2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (20*alpha2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*int2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*int5*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (12*alpha2*CW2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (12*alpha2*CW2*int2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (12*alpha2*CW2*int5*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (16*alpha2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) + 
    (10*alpha2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)) - 
    (2*alpha2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (12*alpha2*CW2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (4*alpha2*int16*MW2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
    (24*alpha2*CW2**2*int16*m_Z*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (4*alpha2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
    (16*alpha2*CW2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*SW*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (4*alpha2*int3*m_Z*SW)/(CW*CW2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
    (4*alpha2*int9*m_Z*SW)/(CW*CW2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
    (2*alpha2*int18*m_h2*m_Z*SW)/(CW*CW2*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int18*m_Z*m_Z2*SW)/(CW*CW2*(-m_h2 + y23 + y24)**2) - 
    (4*alpha2*int23*m_h2*m_Z*m_Z2*SW)/(CW*CW2*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int23*m_Z*m_Z2**2*SW)/(CW*CW2*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int23*m_h2**2*m_Z*m_Z2*SW)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int23*m_h2*m_Z*m_Z2**2*SW)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int18*m_Z*SW*y23)/(CW*CW2*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int23*m_Z*m_Z2*SW*y23)/(CW*CW2*(-m_h2 + y23 + y24)**2) + 
    (6*alpha2*int20*m_h2**2*m_Z*SW)/(CW*CW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
    (8*alpha2*int20*m_h2*m_Z*m_Z2*SW)/(CW*CW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int20*m_h2**3*m_Z*SW)/
    (CW*CW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int20*m_h2**2*m_Z*m_Z2*SW)/
    (CW*CW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
    (4*alpha2*int20*m_h2*m_Z*SW*y23)/(CW*CW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
    (4*alpha2*int20*m_Z*m_Z2*SW*y23)/(CW*CW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int13*m_Z*SW*y24)/(CW*CW2*(-m_h2 + y23 + y24)**2) + 
    (4*alpha2*int18*m_Z*SW*y24)/(CW*CW2*(-m_h2 + y23 + y24)**2) + 
    (4*alpha2*int23*m_h2*m_Z*SW*y24)/(CW*CW2*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int13*m_h2*m_Z*SW*y24)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int18*m_h2*m_Z*SW*y24)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int23*m_h2**2*m_Z*SW*y24)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int13*m_Z*m_Z2*SW*y24)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int18*m_Z*m_Z2*SW*y24)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int23*m_Z*SW*y23*y24)/(CW*CW2*(-m_h2 + y23 + y24)**2) - 
    (12*alpha2*int20*m_h2*m_Z*SW*y24)/
    (CW*CW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
    (8*alpha2*int20*m_Z*m_Z2*SW*y24)/(CW*CW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
    (6*alpha2*int20*m_h2**2*m_Z*SW*y24)/
    (CW*CW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
    (4*alpha2*int20*m_h2*m_Z*m_Z2*SW*y24)/
    (CW*CW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
    (4*alpha2*int20*m_Z*SW*y23*y24)/(CW*CW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
    (4*alpha2*int23*m_Z*SW*y24**2)/(CW*CW2*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int13*m_Z*SW*y24**2)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int18*m_Z*SW*y24**2)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) + 
    (4*alpha2*int23*m_h2*m_Z*SW*y24**2)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int23*m_Z*m_Z2*SW*y24**2)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) + 
    (6*alpha2*int20*m_Z*SW*y24**2)/(CW*CW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
    (6*alpha2*int20*m_h2*m_Z*SW*y24**2)/
    (CW*CW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int20*m_Z*m_Z2*SW*y24**2)/
    (CW*CW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
    (2*alpha2*int23*m_Z*SW*y24**3)/(CW*CW2*y23*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int20*m_Z*SW*y24**3)/
    (CW*CW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
    (2*alpha2*int11*m_Z*SW)/(CW*CW2*(-m_h2 + y23 + y24)) - 
    (2*alpha2*int11*m_h2*m_Z*SW)/(CW*CW2*y23*(-m_h2 + y23 + y24)) + 
    (2*alpha2*int11*m_Z*m_Z2*SW)/(CW*CW2*y23*(-m_h2 + y23 + y24)) + 
    (2*alpha2*int11*m_Z*SW*y24)/(CW*CW2*y23*(-m_h2 + y23 + y24)))

    b1 = ((-2*alpha2*int21*m_Z)/(CW*SW*SW2) + (alpha2*int21*m_Z)/(2.*CW*CW2*SW*SW2) + 
    (2*alpha2*CW2*int21*m_Z)/(CW*SW*SW2) + (alpha2*CW*int24*m_Z)/(SW*SW2) - 
    (2*alpha2*CW*int26*m_Z)/(SW*SW2) - (2*alpha2*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
    (2*alpha2*int5*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) + 
    (32*alpha2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) - 
    (32*alpha2*int1*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) + 
    (32*alpha2*int4*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) - 
    (4*alpha2*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
    (12*alpha2*int5*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
    (16*alpha2*int15*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)) + 
    (16*alpha2*CW*int16*m_Z)/(SW*SW2*(m_h2 - y23)) - 
    (16*alpha2*CW*CW2*int16*m_Z)/(SW*SW2*(m_h2 - y23)) + 
    (2*alpha2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (alpha2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (2.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*CW2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (12*alpha2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (10*alpha2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (32*alpha2*CW2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*m_h2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (alpha2*m_h2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (6*alpha2*CW2*m_h2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (12*alpha2*CW2**2*m_h2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*int11*m_Z)/(CW*SW*SW2*y23) - 
    (alpha2*int11*m_Z)/(2.*CW*CW2*SW*SW2*y23) - 
    (2*alpha2*CW2*int11*m_Z)/(CW*SW*SW2*y23) + 
    (alpha2*CW*int12*m_Z)/(SW*SW2*y23) - (2*alpha2*int13*m_Z)/(CW*SW*SW2*y23) + 
    (alpha2*int13*m_Z)/(2.*CW*CW2*SW*SW2*y23) + 
    (2*alpha2*CW2*int13*m_Z)/(CW*SW*SW2*y23) - 
    (alpha2*CW*int14*m_Z)/(SW*SW2*y23) + (alpha2*CW*int19*m_Z)/(SW*SW2*y23) - 
    (2*alpha2*int20*m_Z)/(CW*SW*SW2*y23) + 
    (alpha2*int20*m_Z)/(2.*CW*CW2*SW*SW2*y23) + 
    (2*alpha2*CW2*int20*m_Z)/(CW*SW*SW2*y23) + 
    (2*alpha2*int21*m_h2*m_Z)/(CW*SW*SW2*y23) - 
    (alpha2*int21*m_h2*m_Z)/(2.*CW*CW2*SW*SW2*y23) - 
    (2*alpha2*CW2*int21*m_h2*m_Z)/(CW*SW*SW2*y23) + 
    (2*alpha2*int21*m_Z*m_Z2)/(CW*SW*SW2*y23) - 
    (alpha2*int21*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y23) - 
    (2*alpha2*CW2*int21*m_Z*m_Z2)/(CW*SW*SW2*y23) - 
    (32*alpha2*m_h2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2*y23) + 
    (16*alpha2*int15*m_h2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)*y23) - 
    (64*alpha2*int15*m_t2**2)/(3.*CW*m_Z*SW*(m_h2 - y23)*y23) - 
    (12*alpha2*CW*int16*m_h2*m_Z)/(SW*SW2*(m_h2 - y23)*y23) + 
    (12*alpha2*CW*CW2*int16*m_h2*m_Z)/(SW*SW2*(m_h2 - y23)*y23) + 
    (24*alpha2*CW*int16*MW2*m_Z)/(SW*SW2*(m_h2 - y23)*y23) - 
    (24*alpha2*CW*CW2**2*int16*m_Z*m_Z2)/(SW*SW2*(m_h2 - y23)*y23) - 
    (2*alpha2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (alpha2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (2.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*CW2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (alpha2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (2.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*CW2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (alpha2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (2.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*CW2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (12*alpha2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (10*alpha2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (32*alpha2*CW2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (12*alpha2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (10*alpha2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (32*alpha2*CW2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (12*alpha2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (10*alpha2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (32*alpha2*CW2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (alpha2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (2*alpha2*int2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (alpha2*int2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (2*alpha2*int5*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (alpha2*int5*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (6*alpha2*CW2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (12*alpha2*CW2**2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (6*alpha2*CW2*int2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (12*alpha2*CW2**2*int2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (6*alpha2*CW2*int5*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
    (12*alpha2*CW2**2*int5*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
    (6*alpha2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (5*alpha2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (16*alpha2*CW2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (24*alpha2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
    (20*alpha2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
    (64*alpha2*CW2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
    (alpha2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (8*alpha2*CW2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
    (12*alpha2*CW2**2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
    (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
    (2*alpha2*int16*MW2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (4*alpha2*CW2*int16*MW2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (12*alpha2*CW2**2*int16*m_Z*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (24*alpha2*CW2**3*int16*m_Z*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (6*alpha2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (5*alpha2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (16*alpha2*CW2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (2*alpha2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (12*alpha2*CW2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (16*alpha2*CW2**2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (alpha2*CW*int12*m_h2*m_Z)/(SW*SW2*y24**2) - 
  (alpha2*CW*int12*MW2*m_Z)/(SW*SW2*y24**2) - 
  (2*alpha2*int11*m_Z*m_Z2)/(CW*SW*SW2*y24**2) + 
  (alpha2*int11*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y24**2) + 
  (2*alpha2*CW2*int11*m_Z*m_Z2)/(CW*SW*SW2*y24**2) - 
  (2*alpha2*int21*m_Z*m_Z2**2)/(CW*SW*SW2*y24**2) + 
  (alpha2*int21*m_Z*m_Z2**2)/(2.*CW*CW2*SW*SW2*y24**2) + 
  (2*alpha2*CW2*int21*m_Z*m_Z2**2)/(CW*SW*SW2*y24**2) - 
  (alpha2*CW*CW2**2*int24*m_Z*m_Z2**2)/(SW*SW2*y24**2) + 
  (alpha2*CW*int16*m_h2**2*m_Z)/(SW*SW2*(m_h2 - y23)*y24**2) + 
  (4*alpha2*CW*int16*m_h2*MW2*m_Z)/(SW*SW2*(m_h2 - y23)*y24**2) + 
  (alpha2*CW*int12*m_h2*MW2*m_Z)/(SW*SW2*y23*y24**2) + 
  (alpha2*CW*int19*m_h2*MW2*m_Z)/(SW*SW2*y23*y24**2) + 
  (2*alpha2*int11*m_h2*m_Z*m_Z2)/(CW*SW*SW2*y23*y24**2) - 
  (alpha2*int11*m_h2*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y23*y24**2) - 
  (2*alpha2*CW2*int11*m_h2*m_Z*m_Z2)/(CW*SW*SW2*y23*y24**2) - 
  (2*alpha2*int20*m_h2*m_Z*m_Z2)/(CW*SW*SW2*y23*y24**2) + 
  (alpha2*int20*m_h2*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y23*y24**2) + 
  (2*alpha2*CW2*int20*m_h2*m_Z*m_Z2)/(CW*SW*SW2*y23*y24**2) + 
  (2*alpha2*int21*m_h2*m_Z*m_Z2**2)/(CW*SW*SW2*y23*y24**2) - 
  (alpha2*int21*m_h2*m_Z*m_Z2**2)/(2.*CW*CW2*SW*SW2*y23*y24**2) - 
  (2*alpha2*CW2*int21*m_h2*m_Z*m_Z2**2)/(CW*SW*SW2*y23*y24**2) + 
  (alpha2*CW*CW2**2*int24*m_h2*m_Z*m_Z2**2)/(SW*SW2*y23*y24**2) - 
  (2*alpha2*CW*int16*m_h2**2*MW2*m_Z)/(SW*SW2*(m_h2 - y23)*y23*y24**2) - 
  (alpha2*CW*int10*m_Z*y23)/(SW*SW2*y24**2) + 
  (alpha2*CW*int12*m_Z*y23)/(SW*SW2*y24**2) - 
  (2*alpha2*CW*int16*m_h2*m_Z*y23)/(SW*SW2*(m_h2 - y23)*y24**2) - 
  (2*alpha2*CW*int16*MW2*m_Z*y23)/(SW*SW2*(m_h2 - y23)*y24**2) + 
  (alpha2*CW*int16*m_Z*y23**2)/(SW*SW2*(m_h2 - y23)*y24**2) + 
  (2*alpha2*int11*m_Z)/(CW*SW*SW2*y24) - 
  (alpha2*int11*m_Z)/(2.*CW*CW2*SW*SW2*y24) - 
  (2*alpha2*CW2*int11*m_Z)/(CW*SW*SW2*y24) + 
  (2*alpha2*CW*int12*m_Z)/(SW*SW2*y24) + 
  (2*alpha2*CW*int24*MW2*m_Z)/(SW*SW2*y24) + 
  (4*alpha2*int21*m_Z*m_Z2)/(CW*SW*SW2*y24) - 
  (alpha2*int21*m_Z*m_Z2)/(CW*CW2*SW*SW2*y24) - 
  (4*alpha2*CW2*int21*m_Z*m_Z2)/(CW*SW*SW2*y24) - 
  (4*alpha2*CW*int16*m_h2*m_Z)/(SW*SW2*(m_h2 - y23)*y24) - 
  (2*alpha2*int11*m_h2*m_Z)/(CW*SW*SW2*y23*y24) + 
  (alpha2*int11*m_h2*m_Z)/(2.*CW*CW2*SW*SW2*y23*y24) + 
  (2*alpha2*CW2*int11*m_h2*m_Z)/(CW*SW*SW2*y23*y24) - 
  (alpha2*CW*int12*m_h2*m_Z)/(SW*SW2*y23*y24) - 
  (alpha2*CW*int19*m_h2*m_Z)/(SW*SW2*y23*y24) + 
  (2*alpha2*int20*m_h2*m_Z)/(CW*SW*SW2*y23*y24) - 
  (alpha2*int20*m_h2*m_Z)/(2.*CW*CW2*SW*SW2*y23*y24) - 
  (2*alpha2*CW2*int20*m_h2*m_Z)/(CW*SW*SW2*y23*y24) - 
  (alpha2*CW*int12*MW2*m_Z)/(SW*SW2*y23*y24) + 
  (alpha2*CW*int14*MW2*m_Z)/(SW*SW2*y23*y24) - 
  (alpha2*CW*int19*MW2*m_Z)/(SW*SW2*y23*y24) - 
  (alpha2*CW*int24*m_h2*MW2*m_Z)/(SW*SW2*y23*y24) - 
  (2*alpha2*int11*m_Z*m_Z2)/(CW*SW*SW2*y23*y24) + 
  (alpha2*int11*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y23*y24) + 
  (2*alpha2*CW2*int11*m_Z*m_Z2)/(CW*SW*SW2*y23*y24) + 
  (2*alpha2*int13*m_Z*m_Z2)/(CW*SW*SW2*y23*y24) - 
  (alpha2*int13*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y23*y24) - 
  (2*alpha2*CW2*int13*m_Z*m_Z2)/(CW*SW*SW2*y23*y24) + 
  (2*alpha2*int20*m_Z*m_Z2)/(CW*SW*SW2*y23*y24) - 
  (alpha2*int20*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y23*y24) - 
  (2*alpha2*CW2*int20*m_Z*m_Z2)/(CW*SW*SW2*y23*y24) - 
  (4*alpha2*int21*m_h2*m_Z*m_Z2)/(CW*SW*SW2*y23*y24) + 
  (alpha2*int21*m_h2*m_Z*m_Z2)/(CW*CW2*SW*SW2*y23*y24) + 
  (4*alpha2*CW2*int21*m_h2*m_Z*m_Z2)/(CW*SW*SW2*y23*y24) + 
  (2*alpha2*CW*int16*m_h2**2*m_Z)/(SW*SW2*(m_h2 - y23)*y23*y24) + 
  (2*alpha2*CW*int16*m_Z*y23)/(SW*SW2*(m_h2 - y23)*y24) - 
  (2*alpha2*int21*m_Z*y24)/(CW*SW*SW2*y23) + 
  (alpha2*int21*m_Z*y24)/(2.*CW*CW2*SW*SW2*y23) + 
  (2*alpha2*CW2*int21*m_Z*y24)/(CW*SW*SW2*y23) + 
  (alpha2*CW*int17*m_Z)/(SW*SW2*(y23 + y24)) + 
  (2*alpha2*m_h2**2)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (2*alpha2*CW2*m_h2**2)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) + 
  (12*alpha2*m_h2*MW2)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (12*alpha2*CW2**2*m_h2*m_Z2)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) + 
  (alpha2*CW*int17*MW2*m_Z)/(SW*SW2*y23*(y23 + y24)) - 
  (2*alpha2*int18*m_Z*m_Z2)/(CW*SW*SW2*y23*(y23 + y24)) + 
  (alpha2*int18*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y23*(y23 + y24)) + 
  (2*alpha2*CW2*int18*m_Z*m_Z2)/(CW*SW*SW2*y23*(y23 + y24)) + 
  (2*alpha2*int2*m_h2*y23)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (2*alpha2*CW2*int2*m_h2*y23)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (8*alpha2*MW2*y23)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) + 
  (12*alpha2*int2*MW2*y23)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) + 
  (8*alpha2*CW2**2*m_Z2*y23)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (12*alpha2*CW2**2*int2*m_Z2*y23)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (alpha2*CW*int17*MW2*m_Z*y23)/(SW*SW2*y24**2*(y23 + y24)) + 
  (2*alpha2*int18*m_Z*m_Z2*y23)/(CW*SW*SW2*y24**2*(y23 + y24)) - 
  (alpha2*int18*m_Z*m_Z2*y23)/(2.*CW*CW2*SW*SW2*y24**2*(y23 + y24)) - 
  (2*alpha2*CW2*int18*m_Z*m_Z2*y23)/(CW*SW*SW2*y24**2*(y23 + y24)) + 
  (alpha2*CW*int17*m_Z*y23**2)/(SW*SW2*y24**2*(y23 + y24)) + 
  (2*alpha2*CW*m_Z)/(SW*SW2*y24*(y23 + y24)) - 
  (4*alpha2*int3*m_Z)/(CW*SW*SW2*y24*(y23 + y24)) + 
  (alpha2*int3*m_Z)/(CW*CW2*SW*SW2*y24*(y23 + y24)) + 
  (4*alpha2*CW2*int3*m_Z)/(CW*SW*SW2*y24*(y23 + y24)) - 
  (2*alpha2*CW*int6*m_Z)/(SW*SW2*y24*(y23 + y24)) + 
  (4*alpha2*int7*m_Z)/(CW*SW*SW2*y24*(y23 + y24)) - 
  (alpha2*int7*m_Z)/(CW*CW2*SW*SW2*y24*(y23 + y24)) - 
  (4*alpha2*CW2*int7*m_Z)/(CW*SW*SW2*y24*(y23 + y24)) - 
  (2*alpha2*CW*int17*MW2*m_Z)/(SW*SW2*y24*(y23 + y24)) + 
  (4*alpha2*int18*m_Z*m_Z2)/(CW*SW*SW2*y24*(y23 + y24)) - 
  (alpha2*int18*m_Z*m_Z2)/(CW*CW2*SW*SW2*y24*(y23 + y24)) - 
  (4*alpha2*CW2*int18*m_Z*m_Z2)/(CW*SW*SW2*y24*(y23 + y24)) - 
  (2*alpha2*m_h2**2*MW2)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*y24*(y23 + y24)) + 
  (2*alpha2*int2*m_h2**2*MW2)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*y24*(y23 + y24)) + 
  (3*alpha2*CW*int17*m_Z*y23)/(SW*SW2*y24*(y23 + y24)) - 
  (2*alpha2*int18*m_Z*y23)/(CW*SW*SW2*y24*(y23 + y24)) + 
  (alpha2*int18*m_Z*y23)/(2.*CW*CW2*SW*SW2*y24*(y23 + y24)) + 
  (2*alpha2*CW2*int18*m_Z*y23)/(CW*SW*SW2*y24*(y23 + y24)) + 
  (4*alpha2*m_h2*MW2*y23)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*y24*(y23 + y24)) - 
  (4*alpha2*int2*m_h2*MW2*y23)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*y24*(y23 + y24)) - 
  (2*alpha2*MW2*y23**2)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*y24*(y23 + y24)) + 
  (2*alpha2*int2*MW2*y23**2)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*y24*(y23 + y24)) + 
  (2*alpha2*int2*m_h2*y24)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (2*alpha2*CW2*int2*m_h2*y24)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (8*alpha2*MW2*y24)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) + 
  (12*alpha2*int2*MW2*y24)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) + 
  (8*alpha2*CW2**2*m_Z2*y24)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (12*alpha2*CW2**2*int2*m_Z2*y24)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*(y23 + y24)) - 
  (alpha2*CW*int17*m_Z*y24)/(SW*SW2*y23*(y23 + y24)) + 
  (2*alpha2*int18*m_Z*y24)/(CW*SW*SW2*y23*(y23 + y24)) - 
  (alpha2*int18*m_Z*y24)/(2.*CW*CW2*SW*SW2*y23*(y23 + y24)) - 
  (2*alpha2*CW2*int18*m_Z*y24)/(CW*SW*SW2*y23*(y23 + y24)) + 
  (2*alpha2*m_h2**2*y24)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(y23 + y24)) - 
  (2*alpha2*CW2*m_h2**2*y24)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(y23 + y24)) + 
  (12*alpha2*m_h2*MW2*y24)/(CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(y23 + y24)) - 
  (12*alpha2*CW2**2*m_h2*m_Z2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(y23 + y24)) + 
  (2*alpha2*CW*int22*m_h2*m_Z)/(SW*SW2*(-m_h2 + y23 + y24)) + 
  (4*alpha2*CW*int22*MW2*m_Z)/(SW*SW2*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*int22*m_h2*MW2*m_Z)/(SW*SW2*y23*(-m_h2 + y23 + y24)) - 
  (3*alpha2*CW*int22*m_Z*y23)/(SW*SW2*(-m_h2 + y23 + y24)) + 
  (2*alpha2*CW*int22*m_h2**2*MW2*m_Z)/(SW*SW2*y24**2*(-m_h2 + y23 + y24)) + 
  (2*alpha2*CW*CW2**2*int22*m_h2*m_Z*m_Z2**2)/
   (SW*SW2*y24**2*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*CW2**2*int22*m_h2**2*m_Z*m_Z2**2)/
   (SW*SW2*y23*y24**2*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*int22*m_h2**2*m_Z*y23)/(SW*SW2*y24**2*(-m_h2 + y23 + y24)) - 
  (4*alpha2*CW*int22*m_h2*MW2*m_Z*y23)/(SW*SW2*y24**2*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*CW2**2*int22*m_Z*m_Z2**2*y23)/(SW*SW2*y24**2*(-m_h2 + y23 + y24)) + 
  (2*alpha2*CW*int22*m_h2*m_Z*y23**2)/(SW*SW2*y24**2*(-m_h2 + y23 + y24)) + 
  (2*alpha2*CW*int22*MW2*m_Z*y23**2)/(SW*SW2*y24**2*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*int22*m_Z*y23**3)/(SW*SW2*y24**2*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*int22*m_h2**2*m_Z)/(SW*SW2*y24*(-m_h2 + y23 + y24)) - 
  (7*alpha2*CW*int22*m_h2*MW2*m_Z)/(SW*SW2*y24*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*CW2**2*int22*m_Z*m_Z2**2)/(SW*SW2*y24*(-m_h2 + y23 + y24)) + 
  (alpha2*CW*int22*m_h2**2*MW2*m_Z)/(SW*SW2*y23*y24*(-m_h2 + y23 + y24)) + 
  (alpha2*CW*CW2**2*int22*m_h2*m_Z*m_Z2**2)/
   (SW*SW2*y23*y24*(-m_h2 + y23 + y24)) + 
  (4*alpha2*CW*int22*m_h2*m_Z*y23)/(SW*SW2*y24*(-m_h2 + y23 + y24)) + 
  (6*alpha2*CW*int22*MW2*m_Z*y23)/(SW*SW2*y24*(-m_h2 + y23 + y24)) - 
  (3*alpha2*CW*int22*m_Z*y23**2)/(SW*SW2*y24*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*int22*m_Z*y24)/(SW*SW2*(-m_h2 + y23 + y24)))


      
    b2 = ((-2*alpha2*CW*int25*m_Z)/(SW*SW2) - (2*alpha2*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
  (2*alpha2*int5*m_h2)/(CW*m_Z*SW*(m_h2 - y23)**2) + 
  (32*alpha2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) - 
  (32*alpha2*int1*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) + 
  (32*alpha2*int4*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2) - 
  (4*alpha2*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
  (12*alpha2*int5*MW2)/(CW*m_Z*SW*(m_h2 - y23)**2) - 
  (16*alpha2*int15*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)) + 
  (2*alpha2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (alpha2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (2.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (2*alpha2*CW2*m_h2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (12*alpha2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (10*alpha2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (32*alpha2*CW2*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (2*alpha2*m_h2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (alpha2*m_h2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (6*alpha2*CW2*m_h2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (12*alpha2*CW2**2*m_h2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (32*alpha2*m_h2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)**2*y23) + 
  (16*alpha2*int15*m_h2*m_t2)/(3.*CW*m_Z*SW*(m_h2 - y23)*y23) - 
  (64*alpha2*int15*m_t2**2)/(3.*CW*m_Z*SW*(m_h2 - y23)*y23) - 
  (2*alpha2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (alpha2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (2.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (2*alpha2*CW2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (2*alpha2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (alpha2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (2.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (2*alpha2*CW2*int2*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (2*alpha2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (alpha2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (2.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (2*alpha2*CW2*int5*m_h2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (12*alpha2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (10*alpha2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (32*alpha2*CW2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (12*alpha2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (10*alpha2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (32*alpha2*CW2*int1*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (12*alpha2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (10*alpha2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (32*alpha2*CW2*int4*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (2*alpha2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (alpha2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (2*alpha2*int2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (alpha2*int2*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (2*alpha2*int5*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (alpha2*int5*MW2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (6*alpha2*CW2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (12*alpha2*CW2**2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (6*alpha2*CW2*int2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (12*alpha2*CW2**2*int2*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (6*alpha2*CW2*int5*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) + 
  (12*alpha2*CW2**2*int5*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(m_h2 - y23)**2) - 
  (6*alpha2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (5*alpha2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (16*alpha2*CW2*int15*m_h2*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (24*alpha2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (20*alpha2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (64*alpha2*CW2*int15*m_t2**2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (alpha2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (8*alpha2*CW2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (12*alpha2*CW2**2*int16*m_h2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (2*alpha2*int16*MW2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (4*alpha2*CW2*int16*MW2*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (12*alpha2*CW2**2*int16*m_Z*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (24*alpha2*CW2**3*int16*m_Z*m_Z2*(Gam_Z*1j*m_Z + m_Z2 - y23))/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (6*alpha2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (5*alpha2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*CW2*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (16*alpha2*CW2*int15*m_t2*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (3.*CW*m_Z*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (2*alpha2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (12*alpha2*CW2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) + 
  (16*alpha2*CW2**2*int16*m_Z*(Gam_Z*1j*m_Z + m_Z2 - y23)*y23)/
   (CW*SW*SW2*(Gam_Z**2*m_Z**2 + (m_Z2 - y23)**2)*(-m_h2 + y23)) - 
  (alpha2*CW*int17*m_h2*m_Z)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int22*m_h2**2*m_Z)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int17*MW2*m_Z)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (3*alpha2*CW*int22*m_h2*MW2*m_Z)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (3*alpha2*CW*int24*m_h2*MW2*m_Z)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (alpha2*CW*CW2**2*int22*m_Z*m_Z2**2)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (alpha2*CW*CW2**2*int24*m_Z*m_Z2**2)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (35*alpha2*CW*int16*m_h2**2*m_Z)/(SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (40*alpha2*CW*CW2*int16*m_h2**2*m_Z)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (44*alpha2*CW*CW2*int16*m_h2*m_Z*m_Z2)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) + 
  (48*alpha2*CW*CW2**2*int16*m_h2*m_Z*m_Z2)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (alpha2*CW*int22*m_h2**2*MW2*m_Z)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) - 
  (alpha2*CW*int24*m_h2**2*MW2*m_Z)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*CW2**2*int22*m_h2*m_Z*m_Z2**2)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*CW2**2*int24*m_h2*m_Z*m_Z2**2)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) - 
  (10*alpha2*CW*int16*m_h2**3*m_Z)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) + 
  (12*alpha2*CW*CW2*int16*m_h2**3*m_Z)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) + 
  (22*alpha2*CW*CW2*int16*m_h2**2*m_Z*m_Z2)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) - 
  (24*alpha2*CW*CW2**2*int16*m_h2**2*m_Z*m_Z2)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) - 
  (alpha2*CW*int10*m_Z*y23)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int17*m_Z*y23)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW*int22*m_h2*m_Z*y23)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW*int22*MW2*m_Z*y23)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW*int24*MW2*m_Z*y23)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (40*alpha2*CW*int16*m_h2*m_Z*y23)/(SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) + 
  (44*alpha2*CW*CW2*int16*m_h2*m_Z*y23)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) + 
  (22*alpha2*CW*CW2*int16*m_Z*m_Z2*y23)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (24*alpha2*CW*CW2**2*int16*m_Z*m_Z2*y23)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int22*m_Z*y23**2)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (15*alpha2*CW*int16*m_Z*y23**2)/(SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (16*alpha2*CW*CW2*int16*m_Z*y23**2)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) + 
  (4*alpha2*CW*int19*m_h2**2*m_Z)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)**2) - 
  (4*alpha2*CW*int19*m_h2*MW2*m_Z)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)**2) - 
  (alpha2*CW*int19*m_h2**3*m_Z)/(SW*SW2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int19*m_h2**2*MW2*m_Z)/
   (SW*SW2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW*int19*m_h2*m_Z*y23)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*CW*int19*MW2*m_Z*y23)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*CW*m_Z)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (4*alpha2*int3*m_Z)/(CW*SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (alpha2*int3*m_Z)/(CW*CW2*SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (4*alpha2*CW2*int3*m_Z)/(CW*SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*CW*int8*m_Z)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (4*alpha2*int9*m_Z)/(CW*SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (alpha2*int9*m_Z)/(CW*CW2*SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (4*alpha2*CW2*int9*m_Z)/(CW*SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*m_h2**3)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (2*alpha2*CW2*m_h2**3)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (2*alpha2*int2*m_h2**3)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*CW2*int2*m_h2**3)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (22*alpha2*CW2*m_h2**2*m_Z2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (20*alpha2*CW2**2*m_h2**2*m_Z2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (14*alpha2*CW2*int2*m_h2**2*m_Z2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (12*alpha2*CW2**2*int2*m_h2**2*m_Z2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (2*alpha2*m_h2**4)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*CW2*m_h2**4)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (12*alpha2*CW2*m_h2**3*m_Z2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (12*alpha2*CW2**2*m_h2**3*m_Z2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*int2*m_h2**2*y23)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (2*alpha2*CW2*int2*m_h2**2*y23)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (12*alpha2*CW2*m_h2*m_Z2*y23)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (8*alpha2*CW2**2*m_h2*m_Z2*y23)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (16*alpha2*CW2*int2*m_h2*m_Z2*y23)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (12*alpha2*CW2**2*int2*m_h2*m_Z2*y23)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*CW2*m_Z2*y23**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (2*alpha2*CW2*int2*m_Z2*y23**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (2*alpha2*int13*m_Z*y24)/(CW*SW*SW2*(m_h2 - y23 - y24)**2) - 
  (alpha2*int13*m_Z*y24)/(2.*CW*CW2*SW*SW2*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW2*int13*m_Z*y24)/(CW*SW*SW2*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*CW*int17*m_Z*y24)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW*int22*m_h2*m_Z*y24)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int24*m_h2*m_Z*y24)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW*int22*MW2*m_Z*y24)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (4*alpha2*CW*int24*MW2*m_Z*y24)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (52*alpha2*CW*int16*m_h2*m_Z*y24)/(SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) + 
  (56*alpha2*CW*CW2*int16*m_h2*m_Z*y24)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) + 
  (48*alpha2*CW*CW2*int16*m_Z*m_Z2*y24)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (48*alpha2*CW*CW2**2*int16*m_Z*m_Z2*y24)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*int13*m_h2*m_Z*y24)/(CW*SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (alpha2*int13*m_h2*m_Z*y24)/(2.*CW*CW2*SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*CW2*int13*m_h2*m_Z*y24)/(CW*SW*SW2*y23*(m_h2 - y23 - y24)**2) - 
  (alpha2*CW*int14*m_h2*m_Z*y24)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) - 
  (alpha2*CW*int17*m_h2*m_Z*y24)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int14*MW2*m_Z*y24)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int17*MW2*m_Z*y24)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int22*m_h2*MW2*m_Z*y24)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int24*m_h2*MW2*m_Z*y24)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*int13*m_Z*m_Z2*y24)/(CW*SW*SW2*y23*(m_h2 - y23 - y24)**2) - 
  (alpha2*int13*m_Z*m_Z2*y24)/(2.*CW*CW2*SW*SW2*y23*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW2*int13*m_Z*m_Z2*y24)/(CW*SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (22*alpha2*CW*int16*m_h2**2*m_Z*y24)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) - 
  (24*alpha2*CW*CW2*int16*m_h2**2*m_Z*y24)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) - 
  (48*alpha2*CW*CW2*int16*m_h2*m_Z*m_Z2*y24)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) + 
  (48*alpha2*CW*CW2**2*int16*m_h2*m_Z*m_Z2*y24)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*CW*int22*m_Z*y23*y24)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (30*alpha2*CW*int16*m_Z*y23*y24)/(SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (32*alpha2*CW*CW2*int16*m_Z*y23*y24)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (8*alpha2*CW*int19*m_h2*m_Z*y24)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (4*alpha2*CW*int19*MW2*m_Z*y24)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (3*alpha2*CW*int19*m_h2**2*m_Z*y24)/
   (SW*SW2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW*int19*m_h2*MW2*m_Z*y24)/
   (SW*SW2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*CW*int19*m_Z*y23*y24)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*m_h2**2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*CW2*m_h2**2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (4*alpha2*int2*m_h2**2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (4*alpha2*CW2*int2*m_h2**2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (28*alpha2*CW2*m_h2*m_Z2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (28*alpha2*CW2**2*m_h2*m_Z2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (24*alpha2*CW2*int2*m_h2*m_Z2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (24*alpha2*CW2**2*int2*m_h2*m_Z2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (4*alpha2*m_h2**3*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (4*alpha2*CW2*m_h2**3*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (24*alpha2*CW2*m_h2**2*m_Z2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (24*alpha2*CW2**2*m_h2**2*m_Z2*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (2*alpha2*int2*m_h2*y23*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*CW2*int2*m_h2*y23*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (8*alpha2*CW2*m_Z2*y23*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (8*alpha2*CW2**2*m_Z2*y23*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (12*alpha2*CW2*int2*m_Z2*y23*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (12*alpha2*CW2**2*int2*m_Z2*y23*y24)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (alpha2*CW*int22*m_Z*y24**2)/(SW*SW2*(m_h2 - y23 - y24)**2) - 
  (alpha2*CW*int24*m_Z*y24**2)/(SW*SW2*(m_h2 - y23 - y24)**2) + 
  (16*alpha2*CW*int16*m_Z*y24**2)/(SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) - 
  (16*alpha2*CW*CW2*int16*m_Z*y24**2)/
   (SW*SW2*(m_h2 - y23)*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*int13*m_Z*y24**2)/(CW*SW*SW2*y23*(m_h2 - y23 - y24)**2) - 
  (alpha2*int13*m_Z*y24**2)/(2.*CW*CW2*SW*SW2*y23*(m_h2 - y23 - y24)**2) - 
  (2*alpha2*CW2*int13*m_Z*y24**2)/(CW*SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int14*m_Z*y24**2)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int17*m_Z*y24**2)/(SW*SW2*y23*(m_h2 - y23 - y24)**2) - 
  (12*alpha2*CW*int16*m_h2*m_Z*y24**2)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) + 
  (12*alpha2*CW*CW2*int16*m_h2*m_Z*y24**2)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) + 
  (24*alpha2*CW*CW2*int16*m_Z*m_Z2*y24**2)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) - 
  (24*alpha2*CW*CW2**2*int16*m_Z*m_Z2*y24**2)/
   (SW*SW2*(m_h2 - y23)*y23*(m_h2 - y23 - y24)**2) + 
  (4*alpha2*CW*int19*m_Z*y24**2)/(SW*SW2*(m_h2 - y24)*(m_h2 - y23 - y24)**2) - 
  (3*alpha2*CW*int19*m_h2*m_Z*y24**2)/
   (SW*SW2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (alpha2*CW*int19*MW2*m_Z*y24**2)/
   (SW*SW2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*int2*m_h2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*CW2*int2*m_h2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (8*alpha2*CW2*m_Z2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (8*alpha2*CW2**2*m_Z2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (12*alpha2*CW2*int2*m_Z2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (12*alpha2*CW2**2*int2*m_Z2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (2*alpha2*m_h2**2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (2*alpha2*CW2*m_h2**2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (12*alpha2*CW2*m_h2*m_Z2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) - 
  (12*alpha2*CW2**2*m_h2*m_Z2*y24**2)/
   (CW*m_Z*SW*SW2*(m_h2 - y23)**2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)) + 
  (alpha2*CW*int19*m_Z*y24**3)/(SW*SW2*y23*(m_h2 - y24)*(m_h2 - y23 - y24)**2) + 
  (2*alpha2*int18*m_h2*m_Z)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int18*m_h2*m_Z)/(2.*CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*CW2*int18*m_h2*m_Z)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int18*m_Z*m_Z2)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int18*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int18*m_Z*m_Z2)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (4*alpha2*int23*m_h2*m_Z*m_Z2)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int23*m_h2*m_Z*m_Z2)/(CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (4*alpha2*CW2*int23*m_h2*m_Z*m_Z2)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int23*m_Z*m_Z2**2)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int23*m_Z*m_Z2**2)/(2.*CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int23*m_Z*m_Z2**2)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int23*m_h2**2*m_Z*m_Z2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int23*m_h2**2*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int23*m_h2**2*m_Z*m_Z2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*int23*m_h2*m_Z*m_Z2**2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int23*m_h2*m_Z*m_Z2**2)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*CW2*int23*m_h2*m_Z*m_Z2**2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int18*m_Z*y23)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int18*m_Z*y23)/(2.*CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int18*m_Z*y23)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int23*m_Z*m_Z2*y23)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int23*m_Z*m_Z2*y23)/(2.*CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int23*m_Z*m_Z2*y23)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (6*alpha2*int20*m_h2**2*m_Z)/(CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (3*alpha2*int20*m_h2**2*m_Z)/
   (2.*CW*CW2*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (6*alpha2*CW2*int20*m_h2**2*m_Z)/
   (CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (8*alpha2*int20*m_h2*m_Z*m_Z2)/(CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int20*m_h2*m_Z*m_Z2)/
   (CW*CW2*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (8*alpha2*CW2*int20*m_h2*m_Z*m_Z2)/
   (CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*int20*m_h2**3*m_Z)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int20*m_h2**3*m_Z)/
   (2.*CW*CW2*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*CW2*int20*m_h2**3*m_Z)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int20*m_h2**2*m_Z*m_Z2)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int20*m_h2**2*m_Z*m_Z2)/
   (2.*CW*CW2*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int20*m_h2**2*m_Z*m_Z2)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (4*alpha2*int20*m_h2*m_Z*y23)/(CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int20*m_h2*m_Z*y23)/
   (CW*CW2*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (4*alpha2*CW2*int20*m_h2*m_Z*y23)/
   (CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (4*alpha2*int20*m_Z*m_Z2*y23)/(CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int20*m_Z*m_Z2*y23)/
   (CW*CW2*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (4*alpha2*CW2*int20*m_Z*m_Z2*y23)/
   (CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (4*alpha2*int18*m_Z*y24)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int18*m_Z*y24)/(CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (4*alpha2*CW2*int18*m_Z*y24)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (4*alpha2*int23*m_h2*m_Z*y24)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int23*m_h2*m_Z*y24)/(CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (4*alpha2*CW2*int23*m_h2*m_Z*y24)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*int18*m_h2*m_Z*y24)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int18*m_h2*m_Z*y24)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*CW2*int18*m_h2*m_Z*y24)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*int23*m_h2**2*m_Z*y24)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int23*m_h2**2*m_Z*y24)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*CW2*int23*m_h2**2*m_Z*y24)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int18*m_Z*m_Z2*y24)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int18*m_Z*m_Z2*y24)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int18*m_Z*m_Z2*y24)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*int23*m_Z*y23*y24)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int23*m_Z*y23*y24)/(2.*CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*CW2*int23*m_Z*y23*y24)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) + 
  (12*alpha2*int20*m_h2*m_Z*y24)/
   (CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (3*alpha2*int20*m_h2*m_Z*y24)/
   (CW*CW2*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (12*alpha2*CW2*int20*m_h2*m_Z*y24)/
   (CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (8*alpha2*int20*m_Z*m_Z2*y24)/(CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*int20*m_Z*m_Z2*y24)/
   (CW*CW2*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (8*alpha2*CW2*int20*m_Z*m_Z2*y24)/
   (CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (6*alpha2*int20*m_h2**2*m_Z*y24)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (3*alpha2*int20*m_h2**2*m_Z*y24)/
   (2.*CW*CW2*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (6*alpha2*CW2*int20*m_h2**2*m_Z*y24)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (4*alpha2*int20*m_h2*m_Z*m_Z2*y24)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int20*m_h2*m_Z*m_Z2*y24)/
   (CW*CW2*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (4*alpha2*CW2*int20*m_h2*m_Z*m_Z2*y24)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (4*alpha2*int20*m_Z*y23*y24)/(CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int20*m_Z*y23*y24)/
   (CW*CW2*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (4*alpha2*CW2*int20*m_Z*y23*y24)/
   (CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (4*alpha2*int23*m_Z*y24**2)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int23*m_Z*y24**2)/(CW*CW2*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (4*alpha2*CW2*int23*m_Z*y24**2)/(CW*SW*SW2*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int18*m_Z*y24**2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int18*m_Z*y24**2)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int18*m_Z*y24**2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (4*alpha2*int23*m_h2*m_Z*y24**2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int23*m_h2*m_Z*y24**2)/(CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (4*alpha2*CW2*int23*m_h2*m_Z*y24**2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*int23*m_Z*m_Z2*y24**2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int23*m_Z*m_Z2*y24**2)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*CW2*int23*m_Z*m_Z2*y24**2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (6*alpha2*int20*m_Z*y24**2)/(CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (3*alpha2*int20*m_Z*y24**2)/
   (2.*CW*CW2*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (6*alpha2*CW2*int20*m_Z*y24**2)/
   (CW*SW*SW2*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (6*alpha2*int20*m_h2*m_Z*y24**2)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (3*alpha2*int20*m_h2*m_Z*y24**2)/
   (2.*CW*CW2*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (6*alpha2*CW2*int20*m_h2*m_Z*y24**2)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int20*m_Z*m_Z2*y24**2)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int20*m_Z*m_Z2*y24**2)/
   (2.*CW*CW2*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int20*m_Z*m_Z2*y24**2)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*int23*m_Z*y24**3)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (alpha2*int23*m_Z*y24**3)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*CW2*int23*m_Z*y24**3)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int20*m_Z*y24**3)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (alpha2*int20*m_Z*y24**3)/
   (2.*CW*CW2*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) + 
  (2*alpha2*CW2*int20*m_Z*y24**3)/
   (CW*SW*SW2*y23*(m_h2 - y24)*(-m_h2 + y23 + y24)**2) - 
  (2*alpha2*int11*m_Z)/(CW*SW*SW2*(-m_h2 + y23 + y24)) + 
  (alpha2*int11*m_Z)/(2.*CW*CW2*SW*SW2*(-m_h2 + y23 + y24)) + 
  (2*alpha2*CW2*int11*m_Z)/(CW*SW*SW2*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*int12*m_Z)/(SW*SW2*(-m_h2 + y23 + y24)) + 
  (2*alpha2*int11*m_h2*m_Z)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)) - 
  (alpha2*int11*m_h2*m_Z)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)) - 
  (2*alpha2*CW2*int11*m_h2*m_Z)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)) + 
  (alpha2*CW*int12*m_h2*m_Z)/(SW*SW2*y23*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*int12*MW2*m_Z)/(SW*SW2*y23*(-m_h2 + y23 + y24)) - 
  (2*alpha2*int11*m_Z*m_Z2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)) + 
  (alpha2*int11*m_Z*m_Z2)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)) + 
  (2*alpha2*CW2*int11*m_Z*m_Z2)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)) - 
  (2*alpha2*int11*m_Z*y24)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)) + 
  (alpha2*int11*m_Z*y24)/(2.*CW*CW2*SW*SW2*y23*(-m_h2 + y23 + y24)) + 
  (2*alpha2*CW2*int11*m_Z*y24)/(CW*SW*SW2*y23*(-m_h2 + y23 + y24)) - 
  (alpha2*CW*int12*m_Z*y24)/(SW*SW2*y23*(-m_h2 + y23 + y24)))


      
    a_1 = abs(a1) ** 2 #abs(coeff_a1(s, t))**2
    a_2 = abs(a2) ** 2 #abs(coeff_a2(s, t))**2
    b_1 = abs(b1) ** 2 #abs(coeff_b1(s, t))**2
    b_2 = abs(b2) ** 2 #abs(coeff_b2(s, t))**2
    
    I = prefac * s * (t ** 2 * (a_1 + b_1) + u ** 2 * (a_2 + b_2))    
    
    dI = np.zeros(nbins, dtype=float)
    dr = (s_max_fix - s_min_fix) / len(dI)
    j = int((s - s_min_fix) / dr)
    dI[j] = I
                                                               
    dI_t = np.zeros(nbins, dtype=float)
    dr_t = (t_max - t_min) / len(dI_t)
    j_t = int((t - t_min) / dr_t)
    dI_t[j_t] = I
        
    return dict(I = I, dI = dI, dI_t = dI_t) 



integ_loop = vegas.Integrator([[0, 1], [0, 1]])
integ_loop(loop_decay, nitn = 2, neval = 10 ** 2)
result = integ_loop(loop_decay, nitn = 3, neval = 10 ** 2)


print(result)
print(result.summary())

print('I =', result['I'])
print('dI =', result['dI'])
print('dI_t =', result['dI_t'])
print('sum(dI/I) =', sum(result['dI']) / result['I'])
print('sum(dI_t/I) =', sum(result['dI_t']) / result['I'])

#resfile = open("dGamma",'w')
#print(result,file = resfile )
#resfile.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-59637ab0276f> in <module>
# ----> 1 import qcdloop as ql
#       2 td = ql.QCDLoop()
#       3 import vegas
#       4 import numpy as np
#       5
#
# ModuleNotFoundError: No module named 'qcdloop'
